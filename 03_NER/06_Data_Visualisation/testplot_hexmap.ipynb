# %%
from hexmap_plot import plot_hex_map

daten = {
    "ZH": 75, "BE": 60, "CH": 20, "ZG": 30, "None": 5
}

plot_hex_map(daten, titel="Vorhandene Datensätze zum Thema \"Parkplätze\"", untertitel="Schematische Darstellung der Verteilung der Suchergebnisse auf die Kantone oder Schweiz")
