# %% [markdown]
# # spacy

# %% [markdown]
# ```bash
# pip install spacy==3.7.2 --only-binary=:all:
# python -m spacy download de_core_news_lg
# ```

# %%
import spacy
nlp = spacy.load("de_core_news_lg")

# %% [markdown]
# ### Test if it works

# %%
text = "Ich bin letzte Woche nach Zürich und Luzern gereist."

doc = nlp(text)

for ent in doc.ents:
    if ent.label_ in ["LOC", "GPE"]:
        print(ent.text, ent.label_)
# Out:
# Zürich LOC
# Luzern LOC

# %%
import pandas as pd
from rich import print
from rich.console import Console
from rich.table import Table
from rich.rule import Rule

number_of_samples = 100


# Load CSV and samples of random rows
csv_path = r"C:\Users\fabia\OneDrive - FHNW\03_FHNW\06_6_Semester\03_6000_BTh\90_Daten_Zwischenablage\02_extracted_keywords_data.csv" 
df = pd.read_csv(csv_path)

sampled_df = df.dropna(subset=["combined_DE_keywords"]).sample(n=number_of_samples, random_state=42)

# Function to extract location phrases
def extract_location_phrases(text):
    doc = nlp(text)
    locations = []

    for i, token in enumerate(doc):
        if token.ent_type_ in ["LOC", "GPE"]:
            if i > 0 and doc[i - 1].text.lower() in ["stadt", "kanton", "region"," gebiet", "land","bezirk"]:
                locations.append(f"{doc[i - 1].text} {token.text}")
            else:
                locations.append(token.text)
    return locations

# Process each sampled line
results = []
for _, row in sampled_df.iterrows():
    keyword_text = str(row["combined_DE_keywords"])
    description_text = str(row.get("dataset_description_DE_preprocessed", ""))
    keyword_locations = extract_location_phrases(keyword_text)
    description_locations = extract_location_phrases(description_text)
    results.append({
        "title": str(row.get("dataset_title_DE_preprocessed", "")),
        "keyword_text": keyword_text,
        "keyword_locations": ", ".join(keyword_locations),
        "description_text": description_text,
        "description_locations": ", ".join(description_locations)
    })


# Display output nicely using rich table
console = Console(width=400)
table = Table(show_header=True, header_style="bold red", show_lines=True)
table.add_column("Title", width=40)
table.add_column("Keywords", width=40)
table.add_column("Locations (Keywords)", style="bold", width=30)
table.add_column("Description", width=40,)
table.add_column("Locations (Description)", style="bold", width=30)

for item in results:
    table.add_row(
        item["title"],
        item["keyword_text"],
        item["keyword_locations"],
        item["description_text"],
        item["description_locations"]
    )

console.print(table)
# Out:
# C:\Temp\QGIS\ipykernel_6924\4116766963.py:12: DtypeWarning: Columns (2,4,6,7,8,9,10,11,12,13,14,16,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Title                                    ┃ Keywords                                 ┃ Locations (Keywords)           ┃ Description                              ┃ Locations (Description)        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Lehrkräfte nach Schuljahr Kanton         │ lehrkräfte nach schuljahr kanton         │                                │ Dieses Dataset präsentiert die           │                                │
# │ Beschäftigungsgrad und Bildungsstufe     │ beschäftigungsgrad und bildungsstufe     │                                │ jährlichen Zahlen der Lehrkräfte in den  │                                │
# │ öffentliche Schulen in Personen          │ öffentliche schulen in personen dieses   │                                │ öffentlichen Schulen nach Bildungsstufe  │                                │
# │                                          │ dataset präsentiert die jährlichen       │                                │ Kanton und Beschäftigungsgrad seit .     │                                │
# │                                          │ zahlen der den öffentlichen seit         │                                │                                          │                                │
# │                                          │ bildungundwissenschaft                   │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ City Statistics Lebensqualität in den    │ city statistics lebensqualität in den    │                                │ nan                                      │ nan                            │
# │ Städten                                  │ städten                                  │                                │                                          │                                │
# │                                          │ nachhaltigeentwicklungregionaleundinter… │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Verlorene potenzielle Lebensjahre Männer │ verlorene potenzielle lebensjahre männer │                                │ nan                                      │ nan                            │
# │                                          │ mann gesundheit                          │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Invasive gebietsfremde Pflanzen          │ invasive gebietsfremde pflanzen          │ schweiz, nachbarländern,       │ Das Set Invasive gebietsfremde Pflanzen  │ der, Schweiz, Schweiz,         │
# │ Potentialkarte Spätblühende Goldrute     │ potentialkarte spätblühende goldrute das │ lausanne, worldclim            │ enthält die Karten der potentiellen      │ Worldclim                      │
# │                                          │ set enthält die karten der potentiellen  │                                │ Verbreitung von in der Schweiz           │                                │
# │                                          │ verbreitung von in schweiz vorkommenden  │                                │ vorkommenden invasiven gebietsfremden    │                                │
# │                                          │ invasiven gebietsfremden arten sowie     │                                │ Arten sowie solchen aus Nachbarländern   │                                │
# │                                          │ solchen aus nachbarländern mit dem       │                                │ mit dem Potential sich in die Schweiz    │                                │
# │                                          │ potential sich auszudehnen die sind das  │                                │ auszudehnen Die Karten sind das Ergebnis │                                │
# │                                          │ ergebnis einer modellierung uni lausanne │                                │ einer Modellierung der Uni Lausanne zur  │                                │
# │                                          │ zur vorhersage welche schwarzen liste    │                                │ Vorhersage der Verbreitung von invasiven │                                │
# │                                          │ resp watchliste aufgeführt modell        │                                │ Pflanzen welche in der Schwarzen Liste   │                                │
# │                                          │ basiert auf den verfügbaren daten gbif   │                                │ resp der Watchliste aufgeführt sind Das  │                                │
# │                                          │ global biodiversity information facility │                                │ Modell basiert auf den verfügbaren Daten │                                │
# │                                          │ verknüpft aktuellen klimadaten worldclim │                                │ von GBIF Global Biodiversity Information │                                │
# │                                          │ 1km auflösung infoflora wsl beinhalten   │                                │ Facility verknüpft mit aktuellen         │                                │
# │                                          │ weitere variablen wie landnutzung und    │                                │ Klimadaten von Worldclim 1km Auflösung   │                                │
# │                                          │ geologie umwelt                          │                                │ sowie den verfügbaren Daten von          │                                │
# │                                          │ bgdibundesgeodateninfrastruktur          │                                │ InfoFlora verknüpft mit Klimadaten der   │                                │
# │                                          │                                          │                                │ WSL Auflösung Die Karten mit Auflösung   │                                │
# │                                          │                                          │                                │ beinhalten weitere Variablen wie         │                                │
# │                                          │                                          │                                │ Landnutzung und Geologie.                │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Fotografien von Max Frisch               │ fotografien von max frisch die           │ frischarchivs,                 │ Die Bilddatenbank des Max Frisch-Archivs │                                │
# │                                          │ bilddatenbank des frischarchivs umfasst  │ schaffensprozesse, zurich      │ umfasst rund Bilder die das Leben Max    │                                │
# │                                          │ rund bilder die das leben frischs        │                                │ Frischs fotografisch dokumentieren und   │                                │
# │                                          │ fotografisch dokumentieren und einen     │                                │ einen umfassenden Einblick in die        │                                │
# │                                          │ umfassenden einblick in                  │                                │ Schaffensprozesse des Schweizer          │                                │
# │                                          │ schaffensprozesse schweizer architekten  │                                │ Architekten und Schriftstellers geben    │                                │
# │                                          │ schriftstellers geben einige dieser      │                                │ Einige dieser Bilder wurden auf          │                                │
# │                                          │ wurden auf wikimedia commons hochgeladen │                                │ Wikimedia Commons hochgeladen.           │                                │
# │                                          │ zurich architektur archiv theater        │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Fliesstiefenkarte EHQ                    │ fliesstiefenkarte ehq die zeigt im       │ kantonsgebiet                  │ Die Fliesstiefenkarte EHQ zeigt im       │ Kantonsgebiet                  │
# │                                          │ massstab die fliesstiefen bei einem      │                                │ Massstab die Fliesstiefen bei einem      │                                │
# │                                          │ extremen hochwasserereignis seltener als │                                │ extremen Hochwasserereignis seltener als │                                │
# │                                          │ jährliches ereignis gefahrenkarten       │                                │ jährliches Ereignis Die Gefahrenkarten   │                                │
# │                                          │ hochwasser liegt für das gesamte         │                                │ Hochwasser liegt für das gesamte         │                                │
# │                                          │ kantonsgebiet vor opendataswiss          │                                │ Kantonsgebiet vor.                       │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Baulinien kommunal kommunale             │ baulinien kommunal kommunale             │ baulinien, gemeinde, bretzwil, │ Stand der Daten Die publizierten Daten   │ Gemeinde, BL,                  │
# │ Nutzungsplanung Gemeinde Bretzwil        │ nutzungsplanung gemeinde bretzwil stand  │ kantons, bl                    │ entsprechen den aktuell von der Gemeinde │ Geometadatensatz, Kanton,      │
# │                                          │ der daten die publizierten entsprechen   │                                │ beschlossenen und vom Regierungsrat      │ Kanton BL                      │
# │                                          │ den aktuell von beschlossenen und vom    │                                │ genehmigten kommunalen Bau uns           │                                │
# │                                          │ regierungsrat genehmigten kommunalen bau │                                │ Strassenlinien Für allgemeine            │                                │
# │                                          │ uns strassenlinien für allgemeine        │                                │ Informationen zu den Daten der           │                                │
# │                                          │ informationen zu des kantons bl          │                                │ kommunalen Bau und Strassenlinien        │                                │
# │                                          │ konsultieren sie bitte geometadatensatz  │                                │ kommunale Nutzungsplanung des Kantons BL │                                │
# │                                          │ kanton bl baulinie nutzungsplan          │                                │ konsultieren Sie bitte den               │                                │
# │                                          │                                          │                                │ Geometadatensatz Baulinien kommunal      │                                │
# │                                          │                                          │                                │ kommunale Nutzungsplanung Kanton BL.     │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ nan                                      │ finanzieller beitrag                     │                                │ nan                                      │ nan                            │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Orthofotos Bünztal                       │ orthofotos bünztal die wurden aus        │ luftbildern, auenschutzpark    │ Die Orthofotos wurden aus farbigen       │ Orthofotos, Auenschutzpark,    │
# │                                          │ farbigen luftbildern erstellt die am mai │                                │ Luftbildern erstellt die am Mai für das  │ Bünztal                        │
# │                                          │ für das projekt auenschutzpark geflogen  │                                │ Projekt Auenschutzpark geflogen wurden   │                                │
# │                                          │ sie decken ab auflösung boden beträgt    │                                │ Sie decken das Bünztal ab Die Auflösung  │                                │
# │                                          │                                          │                                │ am Boden beträgt . .                     │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Status Sozialhilfebeziehende mit         │ status sozialhilfebeziehende mit         │ zivilstand, sozialesicherheit  │ nan                                      │ nan                            │
# │ Schutzstatus ab Jahren nach Zivilstand   │ schutzstatus ab jahren nach zivilstand   │                                │                                          │                                │
# │                                          │ sozialesicherheit                        │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Volksinitiative vom März Für gerechte    │ volksinitiative vom märz für gerechte    │ kanton basellandschaft,        │ Schlussresultate der eidgenössischen     │ Kanton, Kanton                 │
# │ Löhne                                    │ löhne schlussresultate der               │ gemeinden                      │ Abstimmung Volksinitiative vom März Für  │ Basel-Landschaft               │
# │                                          │ eidgenössischen abstimmung november      │                                │ gerechte Löhne November Kanton           │                                │
# │                                          │ kanton basellandschaft aufgeschlüsselt   │                                │ Basel-Landschaft aufgeschlüsselt nach    │                                │
# │                                          │ nach gemeinden abstimmung national       │                                │ Gemeinden.                               │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ swissSURFACE3D Raster Reliefschattierung │ swisssurface3d raster reliefschattierung │ monodirektional, fürstentums,  │ Die Reliefschattierung ist ein Derivat   │ Fürstentums, Liechtenstein     │
# │ monodirektional                          │ monodirektional die ist ein derivat aus  │ liechtenstein, laser, relief   │ aus dem digitalen Höhenmodell            │                                │
# │                                          │ dem digitalen höhenmodell es erlaubt die │                                │ swissSURFACE3D Raster Es erlaubt die     │                                │
# │                                          │ visualisierung des reliefs der schweiz   │                                │ Visualisierung des Reliefs der Schweiz   │                                │
# │                                          │ und fürstentums liechtenstein digitales  │                                │ und des Fürstentums Liechtenstein Die    │                                │
# │                                          │ schummerungsbild bei einem oder mehreren │                                │ Reliefschattierung ist ein digitales     │                                │
# │                                          │ berechneten lichteinfällen darstellung   │                                │ Schummerungsbild bei einem oder mehreren │                                │
# │                                          │ monodirektionalen wurde mit              │                                │ berechneten Lichteinfällen Die           │                                │
# │                                          │ nordwestlichen sonnenstand berechnet     │                                │ Darstellung der monodirektionalen        │                                │
# │                                          │ laser relief geographisches              │                                │ Reliefschattierung aus swissSURFACE3D    │                                │
# │                                          │ informationssystem digitales             │                                │ Raster wurde mit einem nordwestlichen    │                                │
# │                                          │ geländemodell opendataswiss 3d           │                                │ Sonnenstand berechnet.                   │                                │
# │                                          │ simulation dhm (digitales höhenmodell)   │                                │                                          │                                │
# │                                          │ lidar (light detection and ranging) gis  │                                │                                          │                                │
# │                                          │ (geografisches informationssystem)       │                                │                                          │                                │
# │                                          │ laserscanning höhe bgdi                  │                                │                                          │                                │
# │                                          │ bundesgeodateninfrastruktur              │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Schutzpläne der Auengebiete von          │ schutzpläne der auengebiete von          │ teilflächen                    │ Kantonale Schutzpläne zum Schutz und     │                                │
# │ nationaler Bedeutung                     │ nationaler bedeutung kantonale zum       │                                │ Unterhalt der Auengebiete von nationaler │                                │
# │                                          │ schutz und unterhalt gemäss tg nhg rb    │                                │ Bedeutung gemäss TG NHG RB . und RRV NHG │                                │
# │                                          │ rrv rechtlich gesichert mit einer        │                                │ RB . Rechtlich gesichert mit einer       │                                │
# │                                          │ schutzanordnung rrb schutzplan           │                                │ Schutzanordnung RRB Schutzplan und       │                                │
# │                                          │ pflegeplan darin sind perimeter des      │                                │ Pflegeplan Darin sind der Perimeter des  │                                │
# │                                          │ schutzgebietes die waldbauliche          │                                │ Schutzgebietes und die waldbauliche      │                                │
# │                                          │ behandlung teilflächen festgelegt        │                                │ Behandlung der Teilflächen festgelegt.   │                                │
# │                                          │ geodaten                                 │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Referendum Bundesgesetz über die         │ referendum bundesgesetz über die         │ schweiz, gemeinden             │ Referendum Bundesgesetz über die         │ Schweiz                        │
# │ Verminderung von Treibhausgasemissionen  │ verminderung von treibhausgasemissionen  │                                │ Verminderung von Treibhausgasemissionen  │                                │
# │                                          │ kartentypen linien choroplethen          │                                │ Kartentypen Linien Choroplethen          │                                │
# │                                          │ räumliche ausdehnung schweiz zeit        │                                │ Räumliche Ausdehnung Schweiz Zeit        │                                │
# │                                          │ raumeinheiten kantone gemeinden staat    │                                │ Raumeinheiten Kantone Gemeinden          │                                │
# │                                          │ und politik abstimmungen umweltpolitik   │                                │                                          │                                │
# │                                          │ verwaltungseinheiten                     │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Digitales Terrainmodell TIN 3D           │ digitales terrainmodell tin 3d           │                                │ Detaillierte Darstellung des Geländes    │ Terrainmodell                  │
# │                                          │ detaillierte darstellung des geländes    │                                │ Zweck Das digitale Terrainmodell bildet  │                                │
# │                                          │ zweck das digitale bildet die            │                                │ die Bodenoberfläche mit grossem          │                                │
# │                                          │ bodenoberfläche mit grossem              │                                │ Detaillierungsgrad ab Dadurch können     │                                │
# │                                          │ detaillierungsgrad ab dadurch können     │                                │ Kleinstrukturen sichtbar gemacht werden. │                                │
# │                                          │ kleinstrukturen sichtbar gemacht werden  │                                │                                          │                                │
# │                                          │ geodaten tin vektordaten terrainmodell   │                                │                                          │                                │
# │                                          │ erdoberflache lod0 stzh gelandemodell    │                                │                                          │                                │
# │                                          │ geoportal polygondaten                   │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Strassenlänge ohne Nationalstrassen nach │ strassenlänge ohne nationalstrassen nach │ strassenlänge,                 │ Dieses Dataset präsentiert die           │ Fahrbahnlänge                  │
# │ Gemeinde                                 │ gemeinde dieses dataset präsentiert die  │ nationalstrassen               │ jährlichen Zahlen der Fahrbahnlänge in   │                                │
# │                                          │ jährlichen zahlen der fahrbahnlänge in   │                                │ Kilometern nach Kanton und Gemeinde Die  │                                │
# │                                          │ kilometern kanton und die beschreibungen │                                │ Beschreibungen der Variablen in der      │                                │
# │                                          │ variablen csvdatei sind im anhang        │                                │ CSV-Datei sind im Anhang verfügbar.      │                                │
# │                                          │ verfügbar mobilitatundverkehr            │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Politische Geschäfte des Grossen Rats    │ politische geschäfte des grossen rats    │ kantons, thurgau, datensatz,   │ Der Datensatz enthält die politischen    │                                │
# │ des Kantons Thurgau                      │ kantons thurgau der datensatz enthält    │ leistungsmotion, vorstosser,   │ Geschäfte des Grossen Rats seit Über die │                                │
# │                                          │ die politischen seit über                │ parlamentarischeinitiative     │ Geschäftsnummer kann der Datensatz mit   │                                │
# │                                          │ geschäftsnummer kann der mit weiteren    │                                │ weiteren Datensätzen zum Grossen Rat wie │                                │
# │                                          │ datensätzen zum rat wie den              │                                │ den Vorstösserinnen und Vorstösser oder  │                                │
# │                                          │ vorstösserinnen und vorstösser oder      │                                │ den Dokumenten gejoint werden.Die Daten  │                                │
# │                                          │ dokumenten gejoint werdendie daten       │                                │ stammen aus der elektronische            │                                │
# │                                          │ stammen aus elektronische                │                                │ Geschäftsdatenbank des Grossen Rats      │                                │
# │                                          │ geschäftsdatenbank grgeko werden täglich │                                │ GRGEKO und werden täglich automatisiert  │                                │
# │                                          │ automatisiert aktualisiert kantonsrat    │                                │ aktualisiert.                            │                                │
# │                                          │ leistungsmotion grossrat partei grgeko   │                                │                                          │                                │
# │                                          │ kantonsparlament vorstosser grdata       │                                │                                          │                                │
# │                                          │ grossratin parlament vorstosserin        │                                │                                          │                                │
# │                                          │ beschluss parlamentarischeinitiative     │                                │                                          │                                │
# │                                          │ vorstoss einfacheanfrage petition antrag │                                │                                          │                                │
# │                                          │ motion interpellation grosserrat         │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ PW-Neuzulassungen pro Einw Anz.          │ pwneuzulassungen pro einw anz zwischen   │ pwneuzulassungen, zürich,      │ Zwischen dem Oktober des Vorjahres und   │ Kanton, Kanton Zürich          │
# │                                          │ dem oktober des vorjahres und september  │ kantonzuerich                  │ dem September erstmals in Verkehr        │                                │
# │                                          │ erstmals in verkehr gesetzte             │                                │ gesetzte Personenwagen PW geteilt durch  │                                │
# │                                          │ personenwagen pw geteilt durch die       │                                │ die Bevölkerung in Tausend Hinweis Der   │                                │
# │                                          │ bevölkerung tausend hinweis der wert für │                                │ Wert für den ganzen Kanton umfasst alle  │                                │
# │                                          │ den ganzen kanton umfasst alle autos mit │                                │ Autos mit einem Zürcher Kennzeichen      │                                │
# │                                          │ einem zürcher kennzeichen diese können   │                                │ diese können auch Personen oder          │                                │
# │                                          │ auch personen oder unternehmen gehören   │                                │ Unternehmen gehören die ihr Domizil      │                                │
# │                                          │ ihr domizil nicht im zürich haben        │                                │ nicht im Kanton Zürich haben.            │                                │
# │                                          │ kantonzuerich fahrzeuge gemeinden        │                                │                                          │                                │
# │                                          │ bezirke personenwagen motorfahrzeuge     │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Parzellen der SBB                        │ parzellen der sbb übersicht aller        │                                │ Übersicht aller SBB Parzellen            │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Statische Waldgrenzen Oberdorf NW        │ statische waldgrenzen oberdorf nw der    │ oberdorf, geobasisdatensatz,   │ Der Geobasisdatensatz umfasst die        │ Geobasisdatensatz              │
# │                                          │ geobasisdatensatz umfasst die waldgrenze │ bauzonen, waldabstand          │ Waldgrenze innerhalb der Bauzonen wenige │                                │
# │                                          │ innerhalb der bauzonen wenige auch       │                                │ auch ausserhalb mit Beschluss.           │                                │
# │                                          │ ausserhalb mit beschluss forstwirtschaft │                                │                                          │                                │
# │                                          │ wald waldabstand waldfeststellung        │                                │                                          │                                │
# │                                          │ waldfläche waldrand                      │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Erlegtes Wild nach Art nach Kantonen     │ erlegtes wild nach art kantonen          │                                │ nan                                      │ nan                            │
# │                                          │ landundforstwirtschaft                   │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ nan                                      │ tourismus und freizeit stadtplan         │                                │ nan                                      │ nan                            │
# │                                          │ kartographie                             │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Inventar der schützenswerten             │ inventar der schützenswerten             │                                │ Die Karte zeigt die Flächen der          │                                │
# │ Gartenanlagen                            │ gartenanlagen die karte zeigt die        │                                │ inventarisierten Objekte des Inventars   │                                │
# │                                          │ flächen inventarisierten objekte des     │                                │ der schützenswerten Gartenanlagen Die    │                                │
# │                                          │ inventars kriterien zur aufnahme eines   │                                │ Kriterien zur Aufnahme eines Objektes in │                                │
# │                                          │ objektes in das sind im gesetz über den  │                                │ das Inventar sind im Gesetz über den     │                                │
# │                                          │ denkmalschutz definiert garten           │                                │ Denkmalschutz . definiert.               │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Agglomerationsprogramme Massnahmen       │ agglomerationsprogramme massnahmen       │ agglomerationsprogramme,       │ Aargauer Massnahmen der                  │ Aargauer, Limmattal,           │
# │ Flächen                                  │ flächen aargauer der aareland aargauost  │ limmattal                      │ Agglomerationsprogramme AareLand         │ FlächenPolygone                │
# │                                          │ basel und limmattal nur flächenpolygone  │                                │ Aargau-Ost Basel und Limmattal nur       │                                │
# │                                          │ der aktuelle zeitstand enthält die       │                                │ FlächenPolygone Der aktuelle Zeitstand   │                                │
# │                                          │ generation gemäss unterzeichneten        │                                │ enthält die Massnahmen der Generation    │                                │
# │                                          │ leistungsvereinbarungen sowie zum        │                                │ gemäss unterzeichneten                   │                                │
# │                                          │ zeitpunkt eingabe beim bund juni         │                                │ Leistungsvereinbarungen sowie die        │                                │
# │                                          │ opendataswiss                            │                                │ Massnahmen der Generation zum Zeitpunkt  │                                │
# │                                          │                                          │                                │ der Eingabe beim Bund Juni .             │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Lichtsignalanlagen                       │ lichtsignalanlagen im verkehrsgebiet     │ verkehrsgebiet                 │ Lichtsignalanlagen im Verkehrsgebiet     │ Verkehrsgebiet                 │
# │                                          │ erfasst werden attribute wie             │                                │ Erfasst werden . Attribute wie           │                                │
# │                                          │ betriebszeiten oder strassenkategorie    │                                │ Betriebszeiten oder Strassenkategorie.   │                                │
# │                                          │ signalisierung verkehr                   │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Ladestationen für Elektrofahrzeuge       │ ladestationen für elektrofahrzeuge typ   │                                │ Typ und Lokalisierung der Ladestationen  │ Oberrheingebiet                │
# │                                          │ und lokalisierung der im oberrheingebiet │                                │ für Elektrofahrzeuge im Oberrheingebiet  │                                │
# │                                          │ opendata oberrhein verkehrsnetze         │                                │                                          │                                │
# │                                          │ energiequellen fahrzeug                  │                                │                                          │                                │
# │                                          │ energieversorgung                        │                                │                                          │                                │
# │                                          │ elektrizitätsversorgung                  │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Grenzüberschreitender City Statistics    │ grenzüberschreitender city statistics    │                                │ Dieses Dataset präsentiert die           │                                │
# │ Wohnen Agglomerationen                   │ wohnen agglomerationen dieses dataset    │                                │ jährlichen Wohnindikatoren der           │                                │
# │                                          │ präsentiert die jährlichen               │                                │ grenzüberschreitenden City Statistics    │                                │
# │                                          │ wohnindikatoren der                      │                                │ gemäss der Raumtypologie Privathaushalte │                                │
# │                                          │ grenzüberschreitenden gemäss             │                                │ Wohnungen Einfamilienhäuser              │                                │
# │                                          │ raumtypologie privathaushalte wohnungen  │                                │ Haushaltsgrösse Wohnfläche pro Person ab │                                │
# │                                          │ einfamilienhäuser haushaltsgrösse        │                                │ .                                        │                                │
# │                                          │ wohnfläche pro person ab                 │                                │                                          │                                │
# │                                          │ nachhaltigeentwicklungregionaleundinter… │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Rinder Alter von Kühen bei der ersten    │ rinder alter von kühen bei der ersten    │                                │ Verteilung des Alters in Monaten von     │                                │
# │ Abkalbung                                │ abkalbung verteilung des alters in       │                                │ Kühen bei der ersten Abkalbung EKA nach  │                                │
# │                                          │ monaten eka nach jahr schlachtung und    │                                │ Jahr der Schlachtung und nach Rassentyp  │                                │
# │                                          │ rassentyp milchrassen oder fleischrassen │                                │ Milchrassen oder Fleischrassen Das EKA   │                                │
# │                                          │ das wird im bereich form eines boxplots  │                                │ wird im Bereich von Monaten in Form      │                                │
# │                                          │ wiedergegeben die anzahl beobachtungen   │                                │ eines Boxplots wiedergegeben Die Anzahl  │                                │
# │                                          │ pro findet sich csv abkalbung alter      │                                │ Beobachtungen pro Rassentyp und Jahr     │                                │
# │                                          │ rinder nutztiere                         │                                │ findet sich im csv.                      │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Werkkataster übrige Leitungsdaten        │ werkkataster übrige leitungsdaten        │                                │ Erfasste Werkleitungen welche keinem     │                                │
# │                                          │ erfasste werkleitungen welche keinem     │                                │ bestimmten Werk zugewiesen werden        │                                │
# │                                          │ bestimmten werk zugewiesen werden        │                                │ konnten oder von keinem Werk verwaltet   │                                │
# │                                          │ konnten oder von verwaltet werden        │                                │ werden.                                  │                                │
# │                                          │ elektro hausanschlüsse leitungskataster  │                                │                                          │                                │
# │                                          │ leitungsplan privatleitung resttopf      │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ nan                                      │ geobasisdaten                            │                                │ nan                                      │ nan                            │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │  Belegung Intensivpflege Kanton Zürich   │ belegung intensivpflege kanton zürich ab │ kanton, kanton zürich,         │ Anzahl zertifizierte                     │ Spitalebene, Kanton, Kanton    │
# │ ab .. bis ..                             │ bis anzahl zertifizierte                 │ gesundheitsdirektion,          │ Intensivpflege-Betten und deren aktuelle │ Zürich, Variabeln              │
# │                                          │ intensivpflegebetten und deren aktuelle  │ datensatz                      │ Belegung auf Spitalebene im Kanton       │                                │
# ...
# │                                          │ links diese beschränken sich nicht auf   │                                │ enthalten die Sanktionen aller           │                                │
# │                                          │ das eine sondern enthalten die           │                                │ Jugendurteile Ein Vergleich der          │                                │
# │                                          │ sanktionen aller ein vergleich aktuellen │                                │ aktuellen Zahlen mit den Vorjahren ist   │                                │
# │                                          │ mit vorjahren ist somit möglich mann     │                                │ somit nicht möglich.                     │                                │
# │                                          │ frau geschlecht                          │                                │                                          │                                │
# │                                          │ kriminalitatundstrafrecht                │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Schutzbauten Zivilschutz                 │ schutzbauten zivilschutz aktive des      │ ereignisfall, schutzanlagen,   │ Aktive Schutzbauten des Zivilschutzes    │                                │
# │                                          │ zivilschutzes zur unterbringung der      │ bewilligungen, anlagen         │ zur Unterbringung der Bevölkerung oder   │                                │
# │                                          │ bevölkerung oder kulturgütern im         │                                │ Kulturgütern im Ereignisfall Dargestellt │                                │
# │                                          │ ereignisfall dargestellt werden private  │                                │ werden private und öffentliche Gebäude   │                                │
# │                                          │ und öffentliche gebäude mit aktiven      │                                │ mit aktiven Schutzräumen oder            │                                │
# │                                          │ schutzräumen schutzanlagen die nicht     │                                │ Schutzanlagen Schutzbauten die nicht     │                                │
# │                                          │ einem zugeordnet können sind als punkt   │                                │ einem Gebäude zugeordnet werden können   │                                │
# │                                          │ verortet bewilligungen anlagen           │                                │ sind als Punkt verortet.                 │                                │
# │                                          │ sicherheit                               │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Messwerte Buche mittlere stündliche      │ messwerte buche mittlere stündliche      │ messwerte, buche, datensatz    │ Messwerte Buche mittlere stündliche      │ Pollenkonzentration            │
# │ Pollenkonzentration                      │ pollenkonzentration pollen pro           │                                │ Pollenkonzentration Pollen pro           │                                │
# │                                          │ kubikmeter luft daten werden stündlich   │                                │ Kubikmeter Luft Daten werden stündlich   │                                │
# │                                          │ aktualisiert der datensatz enthält alle  │                                │ aktualisiert Der Datensatz enthält alle  │                                │
# │                                          │ messstationen des automatischen          │                                │ Messstationen des automatischen          │                                │
# │                                          │ nationalen pollenmessnetzes allergie     │                                │ nationalen Pollenmessnetzes.             │                                │
# │                                          │ gesundheit hygiene ernährung luft        │                                │                                          │                                │
# │                                          │ atmosphäre atmosphärische bedingungen    │                                │                                          │                                │
# │                                          │ meteorologischgeografische kennwerte     │                                │                                          │                                │
# │                                          │ bgdi bundesgeodateninfrastruktur         │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ AGGLO EVOLUTION DES ZONES DAFFECTATION   │ agglo evolution des zones daffectation   │                                │ Cette couche permet de visualiser les    │                                │
# │ ENTRE ET                                 │ entre et cette couche permet de          │                                │ différence de laffectation du sol du     │                                │
# │                                          │ visualiser les différence laffectation   │                                │ Grand Genève entre et Référez vous aux   │                                │
# │                                          │ du sol grand genève entre et référez     │                                │ couches originales et leur millésimes    │                                │
# │                                          │ vous aux couches originales leur         │                                │ pour plus de détails sur la              │                                │
# │                                          │ millésimes pour plus détails sur la      │                                │ méthodologie.                            │                                │
# │                                          │ méthodologie                             │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Bodenkarte : Wiliberg                    │ bodenkarte wiliberg ab papierkarte       │ bodenkarte, wiliberg           │ Bodenkarte Wiliberg ab Papierkarte       │                                │
# │                                          │ opendataswiss                            │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Waldbrandpräventionsmassnahmen           │ waldbrandpräventionsmassnahmen enthält   │                                │ Enthält die aktuell bestehenden          │                                │
# │                                          │ die aktuell bestehenden                  │                                │ Präventionsmassnahmen der Kantone zur    │                                │
# │                                          │ präventionsmassnahmen der kantone zur    │                                │ Waldbrandgefahr.                         │                                │
# │                                          │ waldbrandgefahr                          │                                │                                          │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Bodenpunktzahl für landwirtschaftlichen  │ bodenpunktzahl für landwirtschaftlichen  │ ertragswertes, geodaten        │ Karte mit digitalisierter                │                                │
# │ Ertragswert                              │ ertragswert karte mit digitalisierter    │                                │ Bodenpunktierung nach der Anleitung für  │                                │
# │                                          │ bodenpunktierung nach der anleitung die  │                                │ die Schätzung des landwirtschaftlichen   │                                │
# │                                          │ schätzung des ertragswertes geodaten     │                                │ Ertragswertes                            │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Gebiete für grosse Windkraftanlagen      │ gebiete für grosse windkraftanlagen      │                                │ Gebiete für grosse Windkraftanlagen mehr │ Richtplankapitel,              │
# │ Richtplan                                │ richtplan mehr als 30m gesamthöhe        │                                │ als 30m Gesamthöhe Richtplankapitel .    │ Windkraft-anlagen,             │
# │                                          │ richtplankapitel windkraftanlagen die    │                                │ Windkraft-anlagen Die Standorte verfügen │ Windkraftanlagen,              │
# │                                          │ standorte verfügen über gute             │                                │ über gute Windverhältnisse Sie kommen    │ Planungsgrundsatz              │
# │                                          │ windverhältnisse sie kommen zur          │                                │ zur vertieften Überprüfung der Eignung   │                                │
# │                                          │ vertieften überprüfung der eignung       │                                │ für Grosswindkraftanlagen für die        │                                │
# │                                          │ grosswindkraftanlagen die kommerzielle   │                                │ kommerzielle grössere mit gutem          │                                │
# │                                          │ grössere mit gutem energieertrag in      │                                │ Energieertrag in Frage Vergleiche        │                                │
# │                                          │ frage vergleiche planungsgrundsatz       │                                │ Richtplankapitel .. Windkraftanlagen     │                                │
# │                                          │                                          │                                │ Planungsgrundsatz .                      │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Messstandorte Gewässerzustand CH         │ messstandorte gewässerzustand ch der     │ datensatz, bund, bundes        │ Der Datensatz stellt die Messstandorte   │ Bund, Bundes                   │
# │                                          │ datensatz stellt die dar an welchen der  │                                │ dar an welchen der Gewässerzustand       │                                │
# │                                          │ erhoben wird die kantone wie in anderen  │                                │ erhoben wird Die Kantone die wie in      │                                │
# │                                          │ umweltbereichen auch im gewässerschutz   │                                │ anderen Umweltbereichen auch im          │                                │
# │                                          │ für den vollzug zuständig sind führen    │                                │ Gewässerschutz für den Vollzug zuständig │                                │
# │                                          │ grossteil untersuchungen gewässer durch  │                                │ sind führen den Grossteil der            │                                │
# │                                          │ bund beschränkt sich auf von nationalem  │                                │ Untersuchungen der Gewässer durch Der    │                                │
# │                                          │ interesse daten und des bundes werden    │                                │ Bund beschränkt sich auf Untersuchungen  │                                │
# │                                          │ vom bundesamt umwelt bafu betriebenen    │                                │ von nationalem Interesse Die Daten der   │                                │
# │                                          │ datenbank dbgz gesammelt gesundheit      │                                │ Kantone und des Bundes werden in der vom │                                │
# │                                          │ sicherheit umweltüberwachung             │                                │ Bundesamt für Umwelt BAFU betriebenen    │                                │
# │                                          │ opendataswiss bgdi                       │                                │ Datenbank Gewässerzustand DBGZ           │                                │
# │                                          │ bundesgeodateninfrastruktur              │                                │ gesammelt.                               │                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┼──────────────────────────────────────────┼────────────────────────────────┤
# │ Historische Bevölkerungsentwicklung der  │ historische bevölkerungsentwicklung der  │ kartentypen, schweiz           │ Historische Bevölkerungsentwicklung der  │ Schweiz                        │
# │ Schweizer Gemeinden                      │ schweizer gemeinden kartentypen symbole  │                                │ Schweizer Gemeinden Kartentypen Symbole  │                                │
# │                                          │ diagramme räumliche ausdehnung schweiz   │                                │ Diagramme Räumliche Ausdehnung Schweiz   │                                │
# │                                          │ zeiten gesellschaft und kultur           │                                │ Zeiten                                   │                                │
# │                                          │ bevölkerung stand entwicklung verteilung │                                │                                          │                                │
# │                                          │ — demografie                             │                                │                                          │                                │
# └──────────────────────────────────────────┴──────────────────────────────────────────┴────────────────────────────────┴──────────────────────────────────────────┴────────────────────────────────┘

# %% [markdown]
# ### Add places to model

# %%
#all_locations = []
import csv
import json

input_csv = r"C:\Users\fabia\OneDrive - FHNW\03_FHNW\06_6_Semester\03_6000_BTh\90_Daten_Zwischenablage\swissnames3d_2024_2056\swissNAMES3D_PLY.csv"
output_jsonl = "gpe_patterns.jsonl"

with open(input_csv, newline='', encoding='utf-8') as csvfile, open(output_jsonl, "w", encoding="utf-8") as jsonlfile:
    reader = csv.DictReader(csvfile, delimiter=';')
    
    for row in reader:
        name = row["NAME"].strip()
        if not name:
            continue
        tokens = name.split()
        pattern = [{"LOWER": token.lower()} for token in tokens]
        entry = {"label": "GPE", "pattern": pattern}
        json.dump(entry, jsonlfile, ensure_ascii=False)
        jsonlfile.write("\n")

print(f"JSONL file created: {output_jsonl}")
# Out:
# JSONL file created: gpe_patterns.jsonl

# %%
# Only certain types of names
import csv
import json
import pandas as pd

# Input/output paths
input_csv = r"C:\Users\fabia\OneDrive - FHNW\03_FHNW\06_6_Semester\03_6000_BTh\90_Daten_Zwischenablage\swissnames3d_2024_2056\swissNAMES3D_PLY.csv"
output_jsonl = "gpe_patterns.jsonl"

# Load CSV and filter by ART
df = pd.read_csv(input_csv, sep=";")
filtered_df = df[df["OBJEKTART"].isin(["Ort"])]
names = filtered_df["NAME"].dropna().unique()

# Write to JSONL
with open(output_jsonl, "w", encoding="utf-8") as f:
    for name in names:
        tokens = name.strip().split()
        if not tokens:
            continue
        pattern = [{"LOWER": token.lower()} for token in tokens]
        json.dump({"label": "GPE", "pattern": pattern}, f, ensure_ascii=False)
        f.write("\n")

print(f"✅ JSONL file created: {output_jsonl}")
# Out:
# ✅ JSONL file created: gpe_patterns.jsonl

# %%
import csv
import json
import pandas as pd
import random
import spacy
from rich import print
from rich.console import Console
from rich.table import Table

# --- Parameters ---
number_of_samples = 100
patterns_file = "gpe_patterns.jsonl"

# --- Step 2: Load and sample main dataset ---
csv_path = r"C:\Users\fabia\OneDrive - FHNW\03_FHNW\06_6_Semester\03_6000_BTh\90_Daten_Zwischenablage\02_extracted_keywords_data.csv"
df = pd.read_csv(csv_path)
sampled_df = df.dropna(subset=["combined_DE_keywords"]).sample(n=number_of_samples, random_state=100)

# --- Step 3: Function to extract locations ---
def run_with_or_without_custom_places(use_custom_places=True):
    nlp_local = spacy.load("de_core_news_lg")

    if use_custom_places:
        ruler = nlp_local.add_pipe("entity_ruler", before="ner")
        with open(patterns_file, "r", encoding="utf-8") as f:
            patterns = [json.loads(line) for line in f]
        ruler.add_patterns(patterns)

    def extract(text):
        doc = nlp_local(text)
        locations = []
        for i, token in enumerate(doc):
            if token.ent_type_ in ["LOC", "GPE"]:
                if i > 0 and doc[i - 1].text.lower() in ["stadt", "kanton", "region"]:
                    phrase = f"{doc[i - 1].text} {token.text}"
                else:
                    phrase = token.text
                locations.append(phrase)
        return locations

    return [
        {
            "title": str(row.get("dataset_title_DE_preprocessed", "")),
            "keywords": str(row["combined_DE_keywords"]),
            "desc": str(row.get("dataset_description_DE_preprocessed", "")),
            "loc_kw": extract(str(row["combined_DE_keywords"])),
            "loc_desc": extract(str(row.get("dataset_description_DE_preprocessed", ""))),
        }
        for _, row in sampled_df.iterrows()
    ]

# --- Step 4: Run both versions (with & without custom places) ---
results_with = run_with_or_without_custom_places(use_custom_places=True)
results_without = run_with_or_without_custom_places(use_custom_places=False)

# --- Step 5: Display comparison in rich table ---
console = Console(width=280)
table = Table(show_header=True, header_style="bold red", show_lines=True)
table.add_column("Title", width=30)
table.add_column("Keywords", width=30)
table.add_column("LOCs (with)", width=25)
table.add_column("LOCs (without)", width=25)

for row_with, row_without in zip(results_with, results_without):
    table.add_row(
        row_with["title"],
        row_with["keywords"],
        ", ".join(row_with["loc_kw"]),
        ", ".join(row_without["loc_kw"])
    )

console.print(table)
# Out:
# C:\Temp\QGIS\ipykernel_16164\2841078494.py:16: DtypeWarning: Columns (2,4,6,7,8,9,10,11,12,13,14,16,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Title                          ┃ Keywords                       ┃ LOCs (with)               ┃ LOCs (without)            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Ruhezonen für Wildtiere        │ ruhezonen für wildtiere        │                           │                           │
# │                                │ wildruhezonen sind säugetiere  │                           │                           │
# │                                │ und vögel wichtige gebiete in  │                           │                           │
# │                                │ denen die bedürfnisse der im   │                           │                           │
# │                                │ vordergrund stehen sie dienen  │                           │                           │
# │                                │ gemäss jagdgesetz art abs des  │                           │                           │
# │                                │ jsg vermeidung übermässiger    │                           │                           │
# │                                │ störung als antwort auf        │                           │                           │
# │                                │ zunehmende freizeitnutzung     │                           │                           │
# │                                │ dürfen während bestimmten      │                           │                           │
# │                                │ jahreszeiten oder einzelnen    │                           │                           │
# │                                │ fällen ganzen jahres nicht nur │                           │                           │
# │                                │ beschränkt freizeitaktivitäten │                           │                           │
# │                                │ genutzt werden opendataswiss   │                           │                           │
# │                                │ wild wildtier schutzgebiet     │                           │                           │
# │                                │ wertetabelle                   │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ AGGLO CORRIDORS ENJEUX         │ agglo corridors enjeux les     │ non, sur                  │                           │
# │                                │ corridors enjeux identifient   │                           │                           │
# │                                │ les lieux importants pour      │                           │                           │
# │                                │ connectivités écologiques du   │                           │                           │
# │                                │ territoireces passages ont été │                           │                           │
# │                                │ délimités dans le cadre des    │                           │                           │
# │                                │ études de base lélaboration    │                           │                           │
# │                                │ contrats biologiques projet    │                           │                           │
# │                                │ dagglomération                 │                           │                           │
# │                                │ francovaldogenevoiscette       │                           │                           │
# │                                │ couche recense espaces         │                           │                           │
# │                                │ linéaires continus ou non      │                           │                           │
# │                                │ bandes boisées chapelet        │                           │                           │
# │                                │ parcelles agricoles extensives │                           │                           │
# │                                │ haie ripisylves cours deau     │                           │                           │
# │                                │ reliant zones réservoirs       │                           │                           │
# │                                │ biodiversité développement     │                           │                           │
# │                                │ relais et permettant           │                           │                           │
# │                                │ déplacement despèces sur       │                           │                           │
# │                                │ larges secteurs                │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Strassenlaermbelastungskatast… │ strassenlaermbelastungskatast… │ strassenlaermbelastungsk… │ strassenlaermbelastungsk… │
# │ WMS                            │ wms des kantons stgallen       │ wms, kantons, stgallen,   │ wms, kantons, stgallen,   │
# │                                │ verkehr lärm opendataswiss     │ lärm, opendataswiss       │ lärm, opendataswiss       │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Akteure des Wissens und        │ akteure des wissens und        │ transferprozess           │ transferprozess           │
# │ Technologietransfers am        │ technologietransfers am        │                           │                           │
# │ Oberrhein                      │ oberrhein interaktive karte    │                           │                           │
# │                                │ der organisationen die im      │                           │                           │
# │                                │ bereich transferprozess tätig  │                           │                           │
# │                                │ sind nach ihrer art oder ihren │                           │                           │
# │                                │ bereichen in denen sie sind    │                           │                           │
# │                                │ forschungseinrichtungen        │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Messdaten zu                   │ messdaten zu ammoniakmessungen │ messdaten, ostschweizer,  │ messdaten, ostschweizer,  │
# │ Ammoniak-Messungen im          │ im robenhuserriet zeitraum der │ fürstentums,              │ fürstentums,              │
# │ Robenhuserriet im Zeitraum     │ vorliegende datensatz ist das  │ liechtenstein, zürich,    │ liechtenstein, kantons,   │
# │                                │ ergebnis eines messprojektes   │ pfäffikersee, wetzikon,   │ zürich, pfäffikersee,     │
# │                                │ von ostluft der                │ kanton                    │ wetzikon, kanton          │
# │                                │ luftqualitätsüberwachung       │                           │                           │
# │                                │ ostschweizer kantone und des   │                           │                           │
# │                                │ fürstentums liechtenstein      │                           │                           │
# │                                │ durchgeführt durch amt für     │                           │                           │
# │                                │ abfall wasser energie luft     │                           │                           │
# │                                │ awel kantons zürich im rahmen  │                           │                           │
# │                                │ wurden in den jahren an einem  │                           │                           │
# │                                │ standort zeitlich              │                           │                           │
# │                                │ hochaufgelöste ammoniak        │                           │                           │
# │                                │ konzentrationen                │                           │                           │
# │                                │ naturschutzgebiet am           │                           │                           │
# │                                │ pfäffikersee bei wetzikon      │                           │                           │
# │                                │ kanton erhoben parallel        │                           │                           │
# │                                │ mittels minidoas sowie         │                           │                           │
# │                                │ meteorologischen messgrössen   │                           │                           │
# │                                │ minutenmittel wurde die        │                           │                           │
# │                                │ ammoniakbelastung sieben       │                           │                           │
# │                                │ standorten mit passivsammlern  │                           │                           │
# │                                │ erfasst mit diesen daten       │                           │                           │
# │                                │ lassen sich typische räumliche │                           │                           │
# │                                │ zeitliche belastungsmuster     │                           │                           │
# │                                │ beschreiben um massgeblichen   │                           │                           │
# │                                │ eintragspfade                  │                           │                           │
# │                                │ ammoniakgebundenem reaktivem   │                           │                           │
# │                                │ stickstoff empfindliche        │                           │                           │
# │                                │ ökosystem aufzuzeigen weitere  │                           │                           │
# │                                │ informationen sind abgelegten  │                           │                           │
# │                                │ datensatzbeschreibung dem      │                           │                           │
# │                                │ verlinkten fachbericht         │                           │                           │
# │                                │ entnehmen messung ammoniak     │                           │                           │
# │                                │ luftqualitaet                  │                           │                           │
# │                                │ naturschutzgebiete             │                           │                           │
# │                                │ luftschadstoffe                │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Inventar der Filterbrunnen     │ inventar der filterbrunnen im  │ filterbrunnen,            │ filterbrunnen, rhoneebene │
# │                                │ landwirtschaftlichen gebiet    │ rhoneebene, brunnen       │                           │
# │                                │ rhoneebene beinhaltet          │                           │                           │
# │                                │ ebenfalls die für gärten       │                           │                           │
# │                                │ genutzt werden landwirtschaft  │                           │                           │
# │                                │ wasser ressourcen              │                           │                           │
# │                                │ ressourcennutzung              │                           │                           │
# │                                │ landwirtschaftliche anlagen    │                           │                           │
# │                                │ und aquakulturanlagen          │                           │                           │
# │                                │ wasserbrunnen wasserbedarf     │                           │                           │
# │                                │ wassergewinnung fassung        │                           │                           │
# │                                │ brunnen geodaten               │                           │                           │
# │                                │ landwirtschaftszone            │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Ständeratswahl Zug             │ ständeratswahl zug             │ ständeratswahl, zug       │ ständeratswahl            │
# │                                │ schlussresultate der           │                           │                           │
# │                                │ kantonalen wahl oktober kanton │                           │                           │
# │                                │ aufgeschlüsselt nach           │                           │                           │
# │                                │ kandidaten und gemeinden       │                           │                           │
# │                                │ kantonal wahl                  │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Ornithologisch wertvolle       │ ornithologisch wertvolle       │                           │                           │
# │ Gebiete wichtige Gebiete inkl  │ gebiete wichtige inkl          │                           │                           │
# │ Bachläufe                      │ bachläufe abgeleiteter         │                           │                           │
# │                                │ datensatz aus dem              │                           │                           │
# │                                │ ornithologischen inventar      │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Gebiete der                    │ gebiete der                    │                           │                           │
# │ grenzüberschreitenden          │ grenzüberschreitenden          │                           │                           │
# │ Zusammenarbeit                 │ zusammenarbeit                 │                           │                           │
# │                                │ grenzüberschreitende           │                           │                           │
# │                                │ kooperationen im               │                           │                           │
# │                                │ oberrheingebiet                │                           │                           │
# │                                │ entwicklungsplan               │                           │                           │
# │                                │ internationale                 │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ CADASTRE TECHNIQUE DU SOUS-SOL │ cadastre technique du soussol  │                           │                           │
# │ GROUPE                         │ groupe le cadastre technique   │                           │                           │
# │                                │ du soussol ctss pour but de    │                           │                           │
# │                                │ recenser et reporter lensemble │                           │                           │
# │                                │ des objets canalisations       │                           │                           │
# │                                │ constructions accessoires la   │                           │                           │
# │                                │ construction occupant le privé │                           │                           │
# │                                │ public façon permanente ne     │                           │                           │
# │                                │ figurant ni dans officiel les  │                           │                           │
# │                                │ cadastres spécifiques services │                           │                           │
# │                                │ publics                        │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ ISOLIGNES CAPACITE CALORIFIQUE │ isolignes capacite calorifique │ maille, au, sauraient,    │ maille, sauraient, aucun, │
# │ MOYENNE SONDES                 │ moyenne sondes de metres       │ aucun, cas, remplacer,    │ cas, remplacer, la,       │
# │                                │ profondeur les isolignes ont   │ la, nécessité, sur        │ nécessité                 │
# │                                │ été calculées partir du modèle │                           │                           │
# │                                │ numérique représentant les     │                           │                           │
# │                                │ variations de capacité         │                           │                           │
# │                                │ calorifique soussol pour des   │                           │                           │
# │                                │ sondes 50m profondeur avec une │                           │                           │
# │                                │ équidistance mjm3 afin donner  │                           │                           │
# │                                │ un rendu plus doux courbes     │                           │                           │
# │                                │ niveaux retravaillées par le   │                           │                           │
# │                                │ biais dun lissage qui ne       │                           │                           │
# │                                │ modifie en rien linformation   │                           │                           │
# │                                │ base modèle maille 5m ces      │                           │                           │
# │                                │ indications caractère général  │                           │                           │
# │                                │ et sont insuffisantes au stade │                           │                           │
# │                                │ projet dexécution elles        │                           │                           │
# │                                │ sauraient aucun cas remplacer  │                           │                           │
# │                                │ la nécessité détudes           │                           │                           │
# │                                │ géotechniques échéant de ces   │                           │                           │
# │                                │ données replacer dans contexte │                           │                           │
# │                                │ global planification           │                           │                           │
# │                                │ multiusages ainsi tout lié il  │                           │                           │
# │                                │ conviendra prendre compte      │                           │                           │
# │                                │ nombreuses thématiques         │                           │                           │
# │                                │ complémentaires telles que     │                           │                           │
# │                                │ protection nappes phréatiques  │                           │                           │
# │                                │ eau potable lutilisation       │                           │                           │
# │                                │ lespace ouvrages               │                           │                           │
# │                                │ infrastructures réseaux divers │                           │                           │
# │                                │ possibilité dextraction        │                           │                           │
# │                                │ matériaux potentiel            │                           │                           │
# │                                │ géothermique rapports sur      │                           │                           │
# │                                │ géothermie genevoise           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ nan                            │ kartographie kartierung        │ plan                      │                           │
# │                                │ industrielle entwicklung plan  │                           │                           │
# │                                │ historische karte              │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Strategische                   │ strategische                   │ alle                      │                           │
# │ Revitalisierungsplanung        │ revitalisierungsplanung        │                           │                           │
# │ Seeufer                        │ seeufer die                    │                           │                           │
# │                                │ gewässerschutzverordnung gschv │                           │                           │
# │                                │ artikel 41d legt die zu        │                           │                           │
# │                                │ revitalisierenden              │                           │                           │
# │                                │ gewässerabschnitte art der     │                           │                           │
# │                                │ revitalisierungsmassnahmen     │                           │                           │
# │                                │ sowie umsetzungsfristen fest   │                           │                           │
# │                                │ innert welcher ökologische     │                           │                           │
# │                                │ aufwertungsmassnahmen          │                           │                           │
# │                                │ umgesetzt werden dabei         │                           │                           │
# │                                │ uferabschnitte identifiziert   │                           │                           │
# │                                │ mit dem grösstmöglichen nutzen │                           │                           │
# │                                │ für natur und landschaft im    │                           │                           │
# │                                │ verhältnis zum                 │                           │                           │
# │                                │ voraussichtlichen aufwand      │                           │                           │
# │                                │ ökologisch aufgewertet können  │                           │                           │
# │                                │ wird alle jahre einen zeitraum │                           │                           │
# │                                │ von jahren erneuert            │                           │                           │
# │                                │ revitalisierung                │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ IMAD IMMEUBLES AVEC            │ imad immeubles avec            │ concus, certains, sans,   │ concus, certains, sans,   │
# │ ENCADREMENT MEDICO-SOCIAL      │ encadrement medicosocial cette │ barrières,                │ barrières,                │
# │                                │ couche permet lidentification  │ architecturales, ils,     │ architecturales, ils,     │
# │                                │ de deux types structures les   │ équipés, dun, système,    │ équipés, dun, système,    │
# │                                │ immeubles encadrement pour     │ dappel, temporaire, répit │ dappel, temporaire, répit │
# │                                │ personnes âgées iepa           │                           │                           │
# │                                │ regroupent des logements       │                           │                           │
# │                                │ indépendants les en âge avs    │                           │                           │
# │                                │ qui sont locataires part       │                           │                           │
# │                                │ entière et locaux communs      │                           │                           │
# │                                │ différentes activités          │                           │                           │
# │                                │ danimation concus certains     │                           │                           │
# │                                │ sans barrières architecturales │                           │                           │
# │                                │ ils équipés dun système dappel │                           │                           │
# │                                │ permettant requérir laide      │                           │                           │
# │                                │ auprès notre personnel         │                           │                           │
# │                                │ dencadrement lunité daccueil   │                           │                           │
# │                                │ temporaire répit uatr          │                           │                           │
# │                                │ accueille un séjour dâge dont  │                           │                           │
# │                                │ laidant naturel etou son       │                           │                           │
# │                                │ réseau est momentanément       │                           │                           │
# │                                │ empêché clients accompagnés    │                           │                           │
# │                                │ dans la vie quotidienne        │                           │                           │
# │                                │ domestique tenant compte leur  │                           │                           │
# │                                │ état santé physique psychique  │                           │                           │
# │                                │ cognitif                       │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Orthofoto Stadt Zürich Sommer  │ orthofoto stadt zürich sommer  │ orthofoto, stadt, stadt   │ orthofoto, stadt, stadt   │
# │                                │ dieses historische wurde       │ zürich, luftbildern,      │ zürich, luftbildern,      │
# │                                │ anhand analoger farbiger       │ geoportal                 │ geoportal                 │
# │                                │ luftbildern von und dem        │                           │                           │
# │                                │ digitalen geländemodell dtm av │                           │                           │
# │                                │ inkl bruchkanten im jahr       │                           │                           │
# │                                │ erstellt die auflösung raster  │                           │                           │
# │                                │ des orthofotos ist 2cm zweck   │                           │                           │
# │                                │ georeferenzdaten orthofoto     │                           │                           │
# │                                │ stzh georeferenzdaten          │                           │                           │
# │                                │ orthophoto geodaten luftbild   │                           │                           │
# │                                │ referenzdaten geoportal        │                           │                           │
# │                                │ rasterdaten                    │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Linthplan Salvetti             │ linthplan salvetti camillo     │                           │                           │
# │                                │ linth xiii sowie molliser      │                           │                           │
# │                                │ naefelser und reichenburger    │                           │                           │
# │                                │ allmendsituationsplan          │                           │                           │
# │                                │ federzeichnung koloriert liar  │                           │                           │
# │                                │ ii mappe historische karte     │                           │                           │
# │                                │ opendataswiss                  │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Kantonsratswahlen Wähleranteil │ kantonsratswahlen wähleranteil │ wähleranteil, fdp,        │ wähleranteil, fdp,        │
# │ FDP                            │ fdp aller listen der partei    │ kantonzuerich             │ kantonzuerich             │
# │                                │ bei den gemeinden              │                           │                           │
# │                                │ kantonzuerich parteien politik │                           │                           │
# │                                │ bezirke kantonsratswahlen      │                           │                           │
# │                                │ wahlen                         │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Felsüberdeckungskarte Kanton   │ felsüberdeckungskarte kanton   │ kanton schaffhausen,      │ kanton, kanton            │
# │ Schaffhausen                   │ schaffhausen die wurde im      │ fels, felsuntergrund,     │ schaffhausen, fels,       │
# │                                │ rahmen der                     │ bohr, untergrunds         │ felsuntergrund, bohr,     │
# │                                │ baugrundklassenkartenerstellu… │                           │ untergrunds               │
# │                                │ erstellt und basiert auf den   │                           │                           │
# │                                │ felsisohypsen dem              │                           │                           │
# │                                │ geländeoberflächenmodell sie   │                           │                           │
# │                                │ anfangs gis aufgeschaltet gibt │                           │                           │
# │                                │ abstand zwischen fels          │                           │                           │
# │                                │ erdoberfläche an damit die     │                           │                           │
# │                                │ mächtigkeit sog lockergesteine │                           │                           │
# │                                │ sich über felsuntergrund       │                           │                           │
# │                                │ befinden wird als flächen      │                           │                           │
# │                                │ polygone dargestellt in        │                           │                           │
# │                                │ klassen unterteilt bis > ist   │                           │                           │
# │                                │ einerseits eine wichtige       │                           │                           │
# │                                │ grundlage zur erstellung       │                           │                           │
# │                                │ seismischen                    │                           │                           │
# │                                │ baugrundklassenkarte           │                           │                           │
# │                                │ andererseits dient sie bei     │                           │                           │
# │                                │ bohr oder bauprojekten         │                           │                           │
# │                                │ einschätzung des untergrunds   │                           │                           │
# │                                │ geologie opendataswiss         │                           │                           │
# │                                │ felsüberdeckung                │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ nan                            │ die alpenkonvention ist ein    │ deutschland, frankreich,  │ deutschland, frankreich,  │
# │                                │ völkerrechtlicher vertrag      │ liechtenstein,            │ liechtenstein,            │
# │                                │ zwischen den acht alpenländern │ österreich, slowenien,    │ österreich, slowenien,    │
# │                                │ deutschland frankreich italien │ schutz, ziel,             │ durchführungsprotokollen  │
# │                                │ liechtenstein monaco           │ durchführungsprotokollen  │                           │
# │                                │ österreich schweiz slowenien   │                           │                           │
# │                                │ sowie der europäischen         │                           │                           │
# │                                │ gemeinschaft zum schutz des    │                           │                           │
# │                                │ besonders sensiblen und        │                           │                           │
# │                                │ verwundbaren ökosystems zur    │                           │                           │
# │                                │ nachhaltigen nutzung           │                           │                           │
# │                                │ alpenraumes philosophie        │                           │                           │
# │                                │ vertrages wird in              │                           │                           │
# │                                │ rahmenkonvention festgehalten  │                           │                           │
# │                                │ deren ziel es bedingungen zu   │                           │                           │
# │                                │ schaffen für eine nachhaltige  │                           │                           │
# │                                │ fördert die                    │                           │                           │
# │                                │ grenzüberschreitende           │                           │                           │
# │                                │ zusammenarbeit lösung          │                           │                           │
# │                                │ gemeinsamer anliegen probleme  │                           │                           │
# │                                │ alpenweite harmonisierung      │                           │                           │
# │                                │ schutzniveaus konkrete         │                           │                           │
# │                                │ schritte handlungs             │                           │                           │
# │                                │ entwicklungsmöglichkeiten aber │                           │                           │
# │                                │ auch massnahmen werden         │                           │                           │
# │                                │ durchführungsprotokollen       │                           │                           │
# │                                │ geregelt diese betreffen       │                           │                           │
# │                                │ themen bergwald                │                           │                           │
# │                                │ berglandwirtschaft bodenschutz │                           │                           │
# │                                │ energie naturschutz            │                           │                           │
# │                                │ landschaftspflege raumplanung  │                           │                           │
# │                                │ entwicklung tourismus verkehr  │                           │                           │
# │                                │ das protokoll streitbeilegung  │                           │                           │
# │                                │ flächenstruktur                │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Geodatenmodell                 │ geodatenmodell minimales zum   │ geodatenmodell, minimales │ geodatenmodell, minimales │
# │                                │ geobasisdatensatz kantonales   │                           │                           │
# │                                │ inventar der kulturgüter von   │                           │                           │
# │                                │ regionaler und lokaler         │                           │                           │
# │                                │ bedeutung identifikator        │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Markierversuche im Grundwasser │ markierversuche im grundwasser │ grundwasser, infotracer,  │ grundwasser, infotracer,  │
# │                                │ sind ein gängiges mittel der   │ ins, markierstoffen,      │ markierstoffen,           │
# │                                │ angewandten hydrogeologie zur  │ überschneidungen, stelle  │ überschneidungen          │
# │                                │ verfolgung des wasserflusses   │                           │                           │
# │                                │ untergrund der layer zeigt die │                           │                           │
# │                                │ eingabestellen aller seit bei  │                           │                           │
# │                                │ infotracer gemeldeten und      │                           │                           │
# │                                │ archivierten ist das           │                           │                           │
# │                                │ instrument bafu koordination   │                           │                           │
# │                                │ zwischen denjenigen stellen    │                           │                           │
# │                                │ durchführen in regel geologie  │                           │                           │
# │                                │ ingenieurbüros sowie           │                           │                           │
# │                                │ forschungsinstitute den        │                           │                           │
# │                                │ kantonalen fachstellen die     │                           │                           │
# │                                │ dargestellten informationen    │                           │                           │
# │                                │ liefern einerseits einen       │                           │                           │
# │                                │ generellen überblick bisher    │                           │                           │
# │                                │ durchgeführten ermöglichen     │                           │                           │
# │                                │ andererseits überprüfung       │                           │                           │
# │                                │ bereichs geplanter versuche    │                           │                           │
# │                                │ markierstoffe werden direkt    │                           │                           │
# │                                │ ins ungesättigte zone oder     │                           │                           │
# │                                │ oberflächengewässer welche mit │                           │                           │
# │                                │ dem verbindung stehen kann     │                           │                           │
# │                                │ eingegeben insbesondere um     │                           │                           │
# │                                │ unnötige eingaben von          │                           │                           │
# │                                │ markierstoffen                 │                           │                           │
# │                                │ überschneidungen               │                           │                           │
# │                                │ unterschiedlicher zu vermeiden │                           │                           │
# │                                │ erfasst auch metadaten datum   │                           │                           │
# │                                │ eingabemilieu verwendeter      │                           │                           │
# │                                │ markierstoff verantwortliche   │                           │                           │
# │                                │ stelle verfügt jedoch über     │                           │                           │
# │                                │ keine angaben deren            │                           │                           │
# │                                │ ergebnissen gewässer bgdi      │                           │                           │
# │                                │ bundesgeodateninfrastruktur    │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Ereigniskataster Hochwasser    │ ereigniskataster hochwasser    │                           │                           │
# │ Überschwemmte Flächen          │ überschwemmte flächen          │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ . Leistungen und Leistungen    │ leistungen und pro unfall nach │ versicherungszweig        │ versicherungszweig        │
# │ pro Unfall nach                │ versicherungszweig seit bei    │                           │                           │
# │ Versicherungszweig seit        │ jahr einheit unfallversicherer │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Modelldokumentation Nationales │ modelldokumentation nationales │                           │                           │
# │ Beobachtungsnetz für           │ beobachtungsnetz für           │                           │                           │
# │ Luftfremdstoffe NABEL          │ luftfremdstoffe nabel das      │                           │                           │
# │                                │ dokument beschreibt die        │                           │                           │
# │                                │ minimalen geodatenmodelle zum  │                           │                           │
# │                                │ geobasidatensatz stationen     │                           │                           │
# │                                │ identifikator objektkatalog    │                           │                           │
# │                                │ geodatenmodell                 │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Studierende an den             │ studierende an den             │ schweiz                   │ schweiz                   │
# │ Fachhochschulen ohne PH nach   │ fachhochschulen ohne ph nach   │                           │                           │
# │ Jahr Fachbereich Studienstufe  │ jahr fachbereich studienstufe  │                           │                           │
# │ Staatsangehörigkeit Kategorie  │ staatsangehörigkeit kategorie  │                           │                           │
# │ und Hochschule                 │ und hochschule dieses dataset  │                           │                           │
# │                                │ präsentiert die jährlichen     │                           │                           │
# │                                │ zahlen der studierenden diplom │                           │                           │
# │                                │ bachelor master weiterbildung  │                           │                           │
# ...
# │                                │ que directeurs zones           │                           │                           │
# │                                │ industrielles pdzi mais aussi  │                           │                           │
# │                                │ site ps loffice patrimoine et  │                           │                           │
# │                                │ sites pourraient également     │                           │                           │
# │                                │ être publiésla thématique      │                           │                           │
# │                                │ permet consulter lensemble     │                           │                           │
# │                                │ données géographiques          │                           │                           │
# │                                │ alphanumériques contenues un   │                           │                           │
# │                                │ mettre regard avec dautres     │                           │                           │
# │                                │ territoriales issues           │                           │                           │
# │                                │ politiques publiques ou        │                           │                           │
# │                                │ référence limites communales   │                           │                           │
# │                                │ cadastre courbes niveau etcles │                           │                           │
# │                                │ sur thème font lobjet dune     │                           │                           │
# │                                │ consultation publique          │                           │                           │
# │                                │ conformément aux exigences     │                           │                           │
# │                                │ légales vigueur les quils      │                           │                           │
# │                                │ contiennent mises disposition  │                           │                           │
# │                                │ partenaires sitg consultables  │                           │                           │
# │                                │ guichetnéanmoins hormis le     │                           │                           │
# │                                │ périmètre validité dun plan    │                           │                           │
# │                                │ adopté qui une valeur légale   │                           │                           │
# │                                │ contraignante autres ne créent │                           │                           │
# │                                │ aucun autre droit obligation   │                           │                           │
# │                                │ ceux découlant textes          │                           │                           │
# │                                │ documents légalement mis       │                           │                           │
# │                                │ procédure adoptés publiésen    │                           │                           │
# │                                │ premier lieu géoréférencer     │                           │                           │
# │                                │ chaque extension chacun        │                           │                           │
# │                                │ éléments constitutifs planil   │                           │                           │
# │                                │ offre unicité représentation   │                           │                           │
# │                                │ graphique standardisée pour    │                           │                           │
# │                                │ grâce charte modèle géomatique │                           │                           │
# │                                │ uniformisésla possibilité      │                           │                           │
# │                                │ représenter simultanément      │                           │                           │
# │                                │ carte numérisés tout           │                           │                           │
# │                                │ genevoisgrand avantage rapport │                           │                           │
# │                                │ au format papier pdf guichet   │                           │                           │
# │                                │ dinterroger donnée contenue    │                           │                           │
# │                                │ couche modèlenote comme        │                           │                           │
# │                                │ numériques se composent        │                           │                           │
# │                                │ équipements distincts deux     │                           │                           │
# │                                │ peuvent consultés séparément   │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Ökomorphologie Seen            │ ökomorphologie seen            │ natürlichkeitsgrad        │ natürlichkeitsgrad        │
# │                                │ natürlichkeitsgrad der seeufer │                           │                           │
# │                                │ nutzen frist und bedeutung in  │                           │                           │
# │                                │ revitalisierungsplanung        │                           │                           │
# │                                │ gewassernetz oekomorphologie   │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Landwerte                      │ landwerte der datensatz        │ datensatz, siedlung       │ datensatz                 │
# │                                │ flächen zeigt die für          │                           │                           │
# │                                │ nutzungen einfamilienhaus      │                           │                           │
# │                                │ stockwerkeigentum sowie        │                           │                           │
# │                                │ gewerbe und industrie          │                           │                           │
# │                                │ liegenschaften innerhalb der   │                           │                           │
# │                                │ bauzone punkte dieselben       │                           │                           │
# │                                │ ausserhalb ausserhalb werden   │                           │                           │
# │                                │ durch sich auf liegenschaft    │                           │                           │
# │                                │ befindenden gebäude            │                           │                           │
# │                                │ visualisiert gebaudeundanlagen │                           │                           │
# │                                │ grundeigentum siedlung         │                           │                           │
# │                                │ wirtschaftlicheaktivitaten     │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Regionale Verkehrskonferenzen  │ regionale verkehrskonferenzen  │                           │                           │
# │                                │ hat der regierungsrat den      │                           │                           │
# │                                │ räumlichen                     │                           │                           │
# │                                │ zuständigkeitsbereich sechs    │                           │                           │
# │                                │ regionalen rvk festgelegt      │                           │                           │
# │                                │ einige gemeinden sind mitglied │                           │                           │
# │                                │ bei einer zweiten              │                           │                           │
# │                                │ doppelmitgliedschaft die       │                           │                           │
# │                                │ grenzen basieren auf           │                           │                           │
# │                                │ generalisierten                │                           │                           │
# │                                │ gemeindengrenzen von           │                           │                           │
# │                                │ regionaleregelung verkehr      │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Bevölkerung nach Stadtkreis    │ bevölkerung nach stadtkreis    │ stadtkreis, stadt, stadt  │ stadtkreis, stadt, stadt  │
# │                                │ wirtschaftliche                │ zürich                    │ zürich                    │
# │                                │ wohnbevölkerung der stadt      │                           │                           │
# │                                │ zürich und jahr                │                           │                           │
# │                                │ bevoelkerungsbestand tabelle   │                           │                           │
# │                                │ zeitreihe sasa sachdaten       │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Basiskarte Zürich Raster       │ basiskarte zürich raster       │ zürich, stadt             │ basiskarte, zürich, stadt │
# │ Stadtplan zu                   │ stadtplan zu die städtische    │                           │                           │
# │                                │ ist ein rasterplan der stadt   │                           │                           │
# │                                │ basiert auf den daten          │                           │                           │
# │                                │ amtlichen vermessung zeigt die │                           │                           │
# │                                │ gebäude und strassen für       │                           │                           │
# │                                │ darstellung im massstab &#     │                           │                           │
# │                                │ optimiert zweck dient als      │                           │                           │
# │                                │ hintergrundkarte überlagerte   │                           │                           │
# │                                │ themen oder übersichtskarte    │                           │                           │
# │                                │ sowohl in ausgedruckter auch   │                           │                           │
# │                                │ digitaler form rasterdaten     │                           │                           │
# │                                │ ubersichtsplan                 │                           │                           │
# │                                │ hintergrundkarte stadtplan     │                           │                           │
# │                                │ ubersichtskarte geoportal      │                           │                           │
# │                                │ hintergrund stzh stadtkarte    │                           │                           │
# │                                │ basiskarte geodaten            │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Modelldokumentation Karten     │ modelldokumentation karten     │ geobasisdatensätzen       │ geobasisdatensätzen       │
# │ gemäss Luftfahrtrecht          │ gemäss luftfahrtrecht          │                           │                           │
# │ Luftfahrtkarten                │ luftfahrtkarten das dokument   │                           │                           │
# │                                │ beschreibt das minimale        │                           │                           │
# │                                │ geodatenmodell zu den          │                           │                           │
# │                                │ geobasisdatensätzen            │                           │                           │
# │                                │ luftfahrtkarte icao schweiz    │                           │                           │
# │                                │ identifikator segelflugkarte   │                           │                           │
# │                                │ darstellungsmodell             │                           │                           │
# │                                │ objektkatalog                  │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Leitungskataster Gemeinde      │ leitungskataster gemeinde      │ oltingen, kantons, bl     │ oltingen, kantons, bl     │
# │ Oltingen                       │ oltingen für allgemeine        │                           │                           │
# │                                │ informationen zum des kantons  │                           │                           │
# │                                │ bl konsultieren sie bitte den  │                           │                           │
# │                                │ geometadatensatz kanton bl     │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Geodatenmodell                 │ geodatenmodell minimales zum   │                           │                           │
# │                                │ geobasidatensatzvorrangfunkti… │                           │                           │
# │                                │ identifikator                  │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Jagdreviere                    │ jagdreviere grenzen der        │ jagdaufseher,             │ jagdaufseher,             │
# │                                │ thurgauer inklusive adressen   │ kontrolliertesjagdgebiet  │ kontrolliertesjagdgebiet  │
# │                                │ jagdaufseher                   │                           │                           │
# │                                │ kontrolliertesjagdgebiet       │                           │                           │
# │                                │ geodaten jagd                  │                           │                           │
# └────────────────────────────────┴────────────────────────────────┴───────────────────────────┴───────────────────────────┘

# %%
# --- Load and sample CSV outside the function ---
import pandas as pd
import json
import spacy

csv_path = r"C:\Users\fabia\OneDrive - FHNW\03_FHNW\06_6_Semester\03_6000_BTh\90_Daten_Zwischenablage\02_extracted_keywords_data.csv"
df = pd.read_csv(csv_path)
sampled_df = df.dropna(subset=["combined_DE_keywords"]).sample(n=100, random_state=42)

# --- Refactored extraction function for DataFrame ---
def extract_locations_from_df(df, patterns_file=None):
    nlp_local = spacy.load("de_core_news_lg")

    if patterns_file:
        ruler = nlp_local.add_pipe("entity_ruler", before="ner")
        with open(patterns_file, "r", encoding="utf-8") as f:
            patterns = [json.loads(line) for line in f]
        ruler.add_patterns(patterns)

    def extract(text):
        doc = nlp_local(text)
        locations = []
        for i, token in enumerate(doc):
            if token.ent_type_ in ["LOC", "GPE"]:
                if i > 0 and doc[i - 1].text.lower() in ["stadt", "kanton", "region"]:
                    phrase = f"{doc[i - 1].text} {token.text}"
                else:
                    phrase = token.text
                locations.append(phrase)
        return locations

    results = []
    for _, row in df.iterrows():
        title = str(row.get("dataset_title_DE_preprocessed", ""))
        keywords = str(row["combined_DE_keywords"])
        desc = str(row.get("dataset_description_DE_preprocessed", ""))

        result = {
            "title": title,
            "keywords": keywords,
            "desc": desc,
            "loc_kw": extract(keywords),
            "loc_desc": extract(desc),
        }
        results.append(result)

    return results

# --- New function to test a single sentence ---
def extract_locations_from_text(text, patterns_file=None):
    nlp_local = spacy.load("de_core_news_lg")

    if patterns_file:
        ruler = nlp_local.add_pipe("entity_ruler", before="ner")
        with open(patterns_file, "r", encoding="utf-8") as f:
            patterns = [json.loads(line) for line in f]
        ruler.add_patterns(patterns)

    doc = nlp_local(text)
    locations = []
    for i, token in enumerate(doc):
        if token.ent_type_ in ["LOC", "GPE"]:
            if i > 0 and doc[i - 1].text.lower() in ["stadt", "kanton", "region"]:
                phrase = f"{doc[i - 1].text} {token.text}"
            else:
                phrase = token.text
            locations.append(phrase)
    return locations

# --- Example usage ---
results_with = extract_locations_from_df(sampled_df, patterns_file="gpe_patterns.jsonl")
results_without = extract_locations_from_df(sampled_df, patterns_file=None)

# --- Example test sentence ---
example_text = "Ich fahre morgen nach Otelfingen, Böckten und Im Löh."
print("Detected locations:", extract_locations_from_text(example_text, patterns_file="gpe_patterns.jsonl"))
# Out:
# C:\Temp\QGIS\ipykernel_23824\3745499240.py:7: DtypeWarning: Columns (2,4,6,7,8,9,10,11,12,13,14,16,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# Detected locations: ['morgen', 'Otelfingen', 'Böckten', 'Löh']

# %% [markdown]
# # bert-base-NER

# %% [markdown]
# ```bash
# pip install --upgrade transformers torch
# pip install accelerate
# ```

# %% [markdown]
# Installation for torch and torchvision without GPU
# ```bash
# pip install --upgrade torch torchvision --index-url https://download.pytorch.org/whl/cpu
# ```

# %%
import torchvision
print(torchvision.__file__)
# Out:
# c:\Users\fabia\anaconda3\lib\site-packages\torchvision\__init__.py

# %%
#Test if torch and torchvision are installed
import torch
import torchvision

print("Torch:", torch.__version__)
print("Torchvision:", torchvision.__version__)
print("Torchvision path:", torchvision.__file__)
# Out:
# Torch: 2.6.0+cpu
# Torchvision: 0.21.0+cpu
# Torchvision path: c:\Users\fabia\anaconda3\lib\site-packages\torchvision\__init__.py

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-large-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-large-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer, grouped_entities=True)

# example1 = "Silas wohnt in Mettmenstetten."
example2 = "Uzwil - GEP Einzugsgebiete"
# example = "inventar der filterbrunnen im landwirtschaftlichen gebiet  rhoneebene beinhaltet ebenfalls die für gärten genutzt werden landwirtschaft wasser ressourcen ressourcennutzung landwirtschaftliche anlagen und aquakulturanlagen wasserbrunnen wasserbedarf wassergewinnung fassung brunnen geodaten landwirtschaftszone."
ner_results = nlp(example2)

for entity in ner_results:
    print(f"{entity['entity_group']}: {entity['word']} ({entity['score']:.2f})")
# Out:
# Some weights of the model checkpoint at dslim/bert-large-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# c:\Users\fabia\anaconda3\lib\site-packages\transformers\pipelines\token_classification.py:170: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# ORG: Bo (0.41)
# LOC: Kantons St. Gallen (0.83)
# ORG: FAL (0.86)
# ORG: Agroscope Reckenh (0.77)
# ORG: ##z (0.86)
# MISC: Bodenp (0.68)
# LOC: ##ald (0.41)

# %% [markdown]
# # Compare BERT vs spacy

# %%
import csv
import json
import pandas as pd
import random
import spacy
from rich import print
from rich.console import Console
from rich.table import Table
from rich.text import Text
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# %%
# --- Step 0: Load models ---
nlp_spacy = spacy.load("de_core_news_lg")
tokenizer = AutoTokenizer.from_pretrained("dslim/bert-large-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-large-NER")
nlp_bert = pipeline("ner", model=model, tokenizer=tokenizer, grouped_entities=True)
# Out:
# Some weights of the model checkpoint at dslim/bert-large-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# c:\Users\fabia\anaconda3\lib\site-packages\transformers\pipelines\token_classification.py:170: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
# --- Step 1: Load and sample dataset ---
def load_sample(csv_path, number_of_samples):
    df = pd.read_csv(csv_path)
    # sampled = df.dropna(subset=["combined_DE_keywords"]).sample(n=min(number_of_samples, len(df)), random_state=100)
    sampled = df.dropna(subset=["dataset_description_DE_preprocessed"]).sample(n=min(number_of_samples, len(df)), random_state=100)

    sampled = sampled.reset_index(drop=True)
    return sampled

# %%
# --- Step 2: spaCy without custom places ---
def extract_with_spacy_default(texts):


    def extract(text):
        doc = nlp_spacy(text)
        locations = []
        for i, token in enumerate(doc):
            if token.ent_type_ in ["LOC", "GPE"]:
                if i > 0 and doc[i - 1].text.lower() in ["stadt", "kanton", "region"]:
                    phrase = f"{doc[i - 1].text} {token.text}"
                else:
                    phrase = token.text
                locations.append(phrase)
        return locations

    return [extract(text) for text in texts]

# %%
import spacy
import json

def extract_with_spacy_custom(texts, patterns_file):
    nlp = spacy.load("de_core_news_lg")
    ruler = nlp.add_pipe("entity_ruler", before="ner")

    # Load your custom patterns
    with open(patterns_file, "r", encoding="utf-8") as f:
        patterns = [json.loads(line) for line in f]
    ruler.add_patterns(patterns)

    # Extract locations only
    def extract(text):
        doc = nlp(text)
        locations = []
        for i, token in enumerate(doc):
            if token.ent_type_ in ["LOC", "GPE"]:
                if i > 0 and doc[i - 1].text.lower() in ["stadt", "kanton", "region"]:
                    phrase = f"{doc[i - 1].text} {token.text}"
                else:
                    phrase = token.text
                locations.append(phrase)
        return locations

    return [extract(text) for text in texts]

# %%
# --- Step 4: transformers NER ---
def extract_with_transformers_batch(texts):
    tokenizer = AutoTokenizer.from_pretrained("dslim/bert-large-NER")
    model = AutoModelForTokenClassification.from_pretrained("dslim/bert-large-NER")
    nlp_bert = pipeline("ner", model=model, tokenizer=tokenizer, grouped_entities=True)

    all_results = []
    for text in texts:
        # Optional: Preprocess to improve recognition (capitalize, simplify)
        cleaned_text = text.strip().capitalize()
        results = nlp_bert(cleaned_text)
        locations = [ent["word"] for ent in results if ent["entity_group"] in ["LOC", "ORG", "PER"]]
        all_results.append(locations)
    return all_results

# %%
import pandas as pd
import re

def simple_match_all(texts):
    # Load Ort-names once
    ort_csv = r"C:\Users\fabia\OneDrive - FHNW\03_FHNW\06_6_Semester\03_6000_BTh\90_Daten_Zwischenablage\swissnames3d_2024_2056\swissNAMES3D_PLY.csv"
    ort_df = pd.read_csv(ort_csv, sep=";")
    print(f"Ort-names loaded from {ort_csv}")
    filtered_ort_names = ort_df["NAME"].dropna().str.lower().unique().tolist()
    # filtered_ort_names = ort_df[ort_df["OBJEKTART"] == "Ort"]["NAME"].dropna().str.lower().unique().tolist()


    # Precompile regex with strict word boundaries (whole word match only)
    regex_list = [re.compile(rf"(?<!\S){re.escape(place)}(?!\S)") for place in filtered_ort_names]

    def match(text):
        text_lower = text.lower()
        return [place for place, pattern in zip(filtered_ort_names, regex_list) if pattern.search(text_lower)]

    return [match(text) for text in texts]

# %%
# --- Step 5: Highlight helper ---
def highlight_matches(text, *other_lists):
    words = [w.strip() for w in text.split(",") if w.strip()]
    all_other_words = set()
    for col in other_lists:
        all_other_words.update([w.strip().lower() for w in col])
    highlighted = Text()
    for i, word in enumerate(words):
        if word.lower() in all_other_words:
            highlighted.append(word, style="bold green")
        else:
            highlighted.append(word)
        if i < len(words) - 1:
            highlighted.append(", ")
    return highlighted

# %%
# --- Step 6: Display results ---
def display_table(df, locs_with, locs_without, locs_transformers,simple_search):
    console = Console(width=300)
    table = Table(show_header=True, header_style="bold red", show_lines=True)
    table.add_column("Title", width=30)
    table.add_column("Keywords", width=30)
    table.add_column("LOCs (with)", width=25)
    table.add_column("LOCs (without)", width=25)
    table.add_column("LOCs (transformers)", width=25)
    table.add_column("Simple search)", width=25)

    row_count = min(len(df), len(locs_with), len(locs_without), len(locs_transformers))
    for i in range(row_count):
        row = df.iloc[i]
        table.add_row(
            str(row.get("dataset_title_DE_preprocessed", "")),
            str(row["dataset_description_DE_preprocessed"]),
            highlight_matches(", ".join(locs_with[i]), locs_without[i], locs_transformers[i]),
            highlight_matches(", ".join(locs_without[i]), locs_with[i], locs_transformers[i]),
            highlight_matches(", ".join(locs_transformers[i]), locs_with[i], locs_without[i]),
            highlight_matches(", ".join(simple_search[i]), locs_with[i], simple_search[i])
        )
    console.print(table)

# %%
number_of_samples = 100
patterns_file = "gpe_patterns.jsonl"
csv_path = r"C:\\Users\\fabia\\OneDrive - FHNW\\03_FHNW\\06_6_Semester\\03_6000_BTh\\90_Daten_Zwischenablage\\02_extracted_keywords_data.csv"

sampled_df = load_sample(csv_path, number_of_samples)
texts = sampled_df["dataset_description_DE_preprocessed"].astype(str).tolist()
# Out:
# C:\Temp\QGIS\ipykernel_26100\838063203.py:3: DtypeWarning: Columns (2,4,6,7,8,9,10,11,12,13,14,16,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)

# %%
locs_with = extract_with_spacy_custom(texts, patterns_file)

# %%
locs_without = extract_with_spacy_default(texts)

# %%
locs_transformers = extract_with_transformers_batch(texts)
# Out:
# Some weights of the model checkpoint at dslim/bert-large-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# c:\Users\fabia\anaconda3\lib\site-packages\transformers\pipelines\token_classification.py:170: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
simple_search = simple_match_all(texts)
# Out:
# Ort-names loaded from C:\Users\fabia\OneDrive -
# FHNW\03_FHNW\06_6_Semester\03_6000_BTh\90_Daten_Zwischenablage\swissnames3d_2024_2056\swissNAMES3D_PLY.csv

# %%
locs_with = extract_with_spacy_custom(texts, patterns_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 locs_with = extract_with_spacy_custom(texts, patterns_file)
#
# Cell In[5], line 3, in extract_with_spacy_custom(texts, patterns_file)
#       2 def extract_with_spacy_custom(texts, patterns_file):
# ----> 3     ruler = nlp_spacy.add_pipe("entity_ruler", before="ner")
#       4     with open(patterns_file, "r", encoding="utf-8") as f:
#       5         patterns = [json.loads(line) for line in f]
#
# File c:\Users\fabia\anaconda3\lib\site-packages\spacy\language.py:810, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     808 name = name if name is not None else factory_name
#     809 if name in self.component_names:
# --> 810     raise ValueError(Errors.E007.format(name=name, opts=self.component_names))
#     811 # Overriding pipe name in the config is not supported and will be ignored.
#     812 if "name" in config:
#
# ValueError: [E007] 'entity_ruler' already exists in pipeline. Existing names: ['tok2vec', 'tagger', 'morphologizer', 'parser', 'lemmatizer', 'senter', 'attribute_ruler', 'entity_ruler', 'ner']

# %%
display_table(sampled_df, locs_with, locs_without, locs_transformers, simple_search)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Title                          ┃ Keywords                       ┃ LOCs (with)               ┃ LOCs (without)            ┃ LOCs (transformers)       ┃ Simple search)            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Waldinventar                   │ Das Waldinventar erfasst jene  │ Waldinventar              │ Waldinventar              │                           │                           │
# │                                │ Waldflächen welche aus         │                           │                           │                           │                           │
# │                                │ naturschützerischer Sicht      │                           │                           │                           │                           │
# │                                │ regionale oder nationale       │                           │                           │                           │                           │
# │                                │ Bedeutung haben Diese Geodaten │                           │                           │                           │                           │
# │                                │ können nur im Intranet genutzt │                           │                           │                           │                           │
# │                                │ werden.                        │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Leitungskataster Strom Erdgas  │ Leitungskataster Strom Erdgas  │ Staffelbach, SIA          │ Staffelbach, SIA          │ ##ska                     │ staffelbach               │
# │ der Gemeinde Staffelbach       │ der Gemeinde Staffelbach in    │                           │                           │                           │                           │
# │                                │ SIA Darstellung                │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Amtliche Vermessung            │ Einteilung des Kantons in      │ Nachführungskreise        │ Nachführungskreise        │                           │                           │
# │ Nachführungskreise             │ Nachführungskreise der         │                           │                           │                           │                           │
# │                                │ amtlichen Vermessung Die       │                           │                           │                           │                           │
# │                                │ Arbeiten der laufenden         │                           │                           │                           │                           │
# │                                │ Nachführung erfolgen durch     │                           │                           │                           │                           │
# │                                │ private patentierte            │                           │                           │                           │                           │
# │                                │ Ingenieur-Geometer welchen die │                           │                           │                           │                           │
# │                                │ Nachführungskreise zugeteilt   │                           │                           │                           │                           │
# │                                │ sind.                          │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Basisplan-AV                   │ Basisplan-AV des Kantons       │ Höhenkurven               │ Höhenkurven               │                           │                           │
# │                                │ Thurgau farbig & schwarzweiss  │                           │                           │                           │                           │
# │                                │ mit Liegenschaften Nomenklatur │                           │                           │                           │                           │
# │                                │ Landes Kantons und             │                           │                           │                           │                           │
# │                                │ Gemeindegrenzen Einzelobjekten │                           │                           │                           │                           │
# │                                │ Bodenbedeckung Strassennamen   │                           │                           │                           │                           │
# │                                │ Höhenkurven und Geländemodell  │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Birs Temperatur Wasserstand    │ Dieser Datensatz zeigt den     │ Birs, Hofmatt,            │ Birs, Hofmatt,            │ m, ##ü, ##nchenstein      │ hofmatt, höhe, siehe,     │
# │ und Abfluss                    │ Wasserstand die Abflussmenge   │ Münchenstein, Höhe,       │ Münchenstein, Höhe,       │                           │ brücke, alle,             │
# │                                │ und die Temperatur der Birs    │ Baselstrasse, Birs, alle  │ Baselstrasse, Birs, alle  │                           │ münchenstein              │
# │                                │ bei Hofmatt in Münchenstein    │                           │                           │                           │                           │
# │                                │ etwa auf Höhe der Brücke       │                           │                           │                           │                           │
# │                                │ Baselstrasse über die Birs Es  │                           │                           │                           │                           │
# │                                │ liegen aktuelle Werte alle     │                           │                           │                           │                           │
# │                                │ Minuten vor Die Messungen      │                           │                           │                           │                           │
# │                                │ werden im Auftrag des          │                           │                           │                           │                           │
# │                                │ Bundesamts für Umwelt          │                           │                           │                           │                           │
# │                                │ durchgeführt siehe             │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ REFPU DS OPB ADOPTE Point      │ Le référentiel des projets     │ plans, Genève, les,       │ plans, Genève, les,       │                           │ au, plans, plan, les      │
# │                                │ urbains RefPU est la version   │ plans, les, plans, les,   │ plans, les, plans, les,   │                           │ plans, site, font,        │
# │                                │ numérique des plans            │ plans, La, thématique,    │ plans, La, thématique,    │                           │ premier, dun, sur, canton │
# │                                │ daffectations produits par     │ RefPU, permet, de,        │ RefPU, permet, de,        │                           │                           │
# │                                │ lautorité compétente en        │ consulter, lensemble,     │ consulter, lensemble,     │                           │                           │
# │                                │ matière daménagement du        │ Les, PLQ, publiés, sur,   │ Les, PLQ, publiés, sur,   │                           │                           │
# │                                │ territoire du canton de        │ font, sur, plan, premier, │ font, sur, plan, premier, │                           │                           │
# │                                │ Genève.Pour lheure seuls les   │ plan, plan, plans, sur,   │ plan, plan, plans, sur,   │                           │                           │
# │                                │ plans localisés de quartier    │ au, sur, plan, plan,      │ au, sur, plan, plan,      │                           │                           │
# │                                │ PLQ sont publiés dans ce       │ daménagement, et, dun,    │ daménagement, et, dun,    │                           │                           │
# │                                │ référentiel terme les          │ plan, plans               │ plan, plans               │                           │                           │
# │                                │ modifications de zone MZ ainsi │                           │                           │                           │                           │
# │                                │ que les plans directeurs de    │                           │                           │                           │                           │
# │                                │ zones industrielles PDZI mais  │                           │                           │                           │                           │
# │                                │ aussi les plans de site PS     │                           │                           │                           │                           │
# │                                │ produits par loffice du        │                           │                           │                           │                           │
# │                                │ patrimoine et des sites        │                           │                           │                           │                           │
# │                                │ pourraient également être      │                           │                           │                           │                           │
# │                                │ publiés.La thématique RefPU    │                           │                           │                           │                           │
# │                                │ permet de consulter lensemble  │                           │                           │                           │                           │
# │                                │ des données géographiques et   │                           │                           │                           │                           │
# │                                │ alphanumériques contenues dans │                           │                           │                           │                           │
# │                                │ un PLQ et de les mettre en     │                           │                           │                           │                           │
# │                                │ regard avec dautres données    │                           │                           │                           │                           │
# │                                │ territoriales issues dautres   │                           │                           │                           │                           │
# │                                │ politiques publiques ou des    │                           │                           │                           │                           │
# │                                │ données de référence limites   │                           │                           │                           │                           │
# │                                │ communales cadastre courbes de │                           │                           │                           │                           │
# │                                │ niveau etc..Les PLQ publiés    │                           │                           │                           │                           │
# │                                │ sur ce thème font lobjet dune  │                           │                           │                           │                           │
# │                                │ consultation publique          │                           │                           │                           │                           │
# │                                │ conformément aux exigences     │                           │                           │                           │                           │
# │                                │ légales en vigueur Les données │                           │                           │                           │                           │
# │                                │ quils contiennent sont mises   │                           │                           │                           │                           │
# │                                │ la disposition des partenaires │                           │                           │                           │                           │
# │                                │ du SITG et consultables sur ce │                           │                           │                           │                           │
# │                                │ guichet.Néanmoins hormis le    │                           │                           │                           │                           │
# │                                │ périmètre de validité dun plan │                           │                           │                           │                           │
# │                                │ adopté qui une valeur légale   │                           │                           │                           │                           │
# │                                │ contraignante les autres       │                           │                           │                           │                           │
# │                                │ données géographiques et       │                           │                           │                           │                           │
# │                                │ alphanumériques mises          │                           │                           │                           │                           │
# │                                │ disposition ne créent aucun    │                           │                           │                           │                           │
# │                                │ autre droit ou obligation que  │                           │                           │                           │                           │
# │                                │ ceux découlant des textes et   │                           │                           │                           │                           │
# │                                │ documents légalement mis en    │                           │                           │                           │                           │
# │                                │ procédure adoptés et           │                           │                           │                           │                           │
# │                                │ publiés.En premier lieu le     │                           │                           │                           │                           │
# │                                │ RefPU permet de géoréférencer  │                           │                           │                           │                           │
# │                                │ chaque plan et par extension   │                           │                           │                           │                           │
# │                                │ chacun des éléments            │                           │                           │                           │                           │
# │                                │ constitutifs du plan.Il offre  │                           │                           │                           │                           │
# │                                │ également une unicité de       │                           │                           │                           │                           │
# │                                │ représentation graphique       │                           │                           │                           │                           │
# │                                │ standardisée pour lensemble    │                           │                           │                           │                           │
# │                                │ des plans localisés de         │                           │                           │                           │                           │
# │                                │ quartier grâce une charte      │                           │                           │                           │                           │
# │                                │ graphique et un modèle de      │                           │                           │                           │                           │
# │                                │ données géomatique             │                           │                           │                           │                           │
# │                                │ uniformisés.La thématique      │                           │                           │                           │                           │
# │                                │ RefPU offre également la       │                           │                           │                           │                           │
# │                                │ possibilité de représenter     │                           │                           │                           │                           │
# │                                │ simultanément dans une carte   │                           │                           │                           │                           │
# │                                │ numérique lensemble des PLQ    │                           │                           │                           │                           │
# │                                │ numérisés sur tout le          │                           │                           │                           │                           │
# │                                │ territoire genevois.Grand      │                           │                           │                           │                           │
# │                                │ avantage par rapport au format │                           │                           │                           │                           │
# │                                │ papier ou pdf le guichet       │                           │                           │                           │                           │
# │                                │ numérique permet dinterroger   │                           │                           │                           │                           │
# │                                │ la valeur de chaque donnée     │                           │                           │                           │                           │
# │                                │ contenue dans une couche du    │                           │                           │                           │                           │
# │                                │ modèle.Note tout comme sur un  │                           │                           │                           │                           │
# │                                │ plan en format papier ou pdf   │                           │                           │                           │                           │
# │                                │ les PLQ numériques se          │                           │                           │                           │                           │
# │                                │ composent dun plan             │                           │                           │                           │                           │
# │                                │ daménagement et dun plan des   │                           │                           │                           │                           │
# │                                │ équipements distincts Les deux │                           │                           │                           │                           │
# │                                │ plans peuvent être consultés   │                           │                           │                           │                           │
# │                                │ séparément.                    │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ ITINERAIRES DE LOISIRS         │ Différentes catégories de      │ sur                       │ sur                       │                           │ sur                       │
# │                                │ loisirs dans la nature sont    │                           │                           │                           │                           │
# │                                │ prévus dêtre intégrés sur le   │                           │                           │                           │                           │
# │                                │ serveur du SITG On notera      │                           │                           │                           │                           │
# │                                │ entre autre les parcours       │                           │                           │                           │                           │
# │                                │ cavaliers balisés les sentiers │                           │                           │                           │                           │
# │                                │ thèmes les sentiers            │                           │                           │                           │                           │
# │                                │ accessibles aux handicapés     │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Marktwirtschaftliche           │ Dieses Dataset präsentiert die │                           │                           │                           │                           │
# │ Unternehmen nach               │ jährlichen Daten der           │                           │                           │                           │                           │
# │ Wirtschaftsabteilungen und     │ marktwirtschaftlichen          │                           │                           │                           │                           │
# │ Grössenklasse                  │ Unternehmen und der            │                           │                           │                           │                           │
# │                                │ Beschäftigten nach             │                           │                           │                           │                           │
# │                                │ Wirtschaftszweig und           │                           │                           │                           │                           │
# │                                │ Grössenklasse Anzahl           │                           │                           │                           │                           │
# │                                │ Beschäftigte seit Die          │                           │                           │                           │                           │
# │                                │ Beschreibungen der Variablen   │                           │                           │                           │                           │
# │                                │ in der CSV-Datei sind im       │                           │                           │                           │                           │
# │                                │ Anhang verfügbar.              │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Statische Waldgrenzen Gemeinde │ Stand der Daten Die            │ neuen, Kantons, BL,       │ neuen, Kantons, BL,       │                           │ neuen                     │
# │ Wahlen                         │ publizierten Daten entsprechen │ Kanton, Kanton BL         │ Kanton, Kanton BL         │                           │                           │
# │                                │ den aktuell vom Regierungsrat  │                           │                           │                           │                           │
# │                                │ genehmigten statischen         │                           │                           │                           │                           │
# │                                │ Waldgrenzen Die Nachführung    │                           │                           │                           │                           │
# │                                │ erfolgt in der Regel als Folge │                           │                           │                           │                           │
# │                                │ einer neuen                    │                           │                           │                           │                           │
# │                                │ Waldfeststellungsverfügung     │                           │                           │                           │                           │
# │                                │ oder einer Rodungsbewilligung  │                           │                           │                           │                           │
# │                                │ Für allgemeine Informationen   │                           │                           │                           │                           │
# │                                │ zu den Daten der statische     │                           │                           │                           │                           │
# │                                │ Waldgrenzen des Kantons BL     │                           │                           │                           │                           │
# │                                │ konsultieren Sie bitte den     │                           │                           │                           │                           │
# │                                │ Geometadatensatz Statische     │                           │                           │                           │                           │
# │                                │ Waldgrenzen Kanton BL.         │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Messstellen Grundwasser        │ Uebersicht der hydrometrischen │ Kanton St., Gallen        │ Kanton St., Gallen        │ ##len                     │                           │
# │ Hydrometrie WMS                │ Grundwasser-Messstellen im     │                           │                           │                           │                           │
# │                                │ Kanton St.Gallen.              │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Liniennetz des öffentlichen    │ Der Datensatz zeigt das        │ Kanton, Kanton            │ Kanton, Kanton            │                           │                           │
# │ Verkehrs                       │ Liniennetz des öffentlichen    │ Basel-Stadt               │ Basel-Stadt               │                           │                           │
# │                                │ Verkehrs im Kanton Basel-Stadt │                           │                           │                           │                           │
# │                                │ sowie teilweise in der         │                           │                           │                           │                           │
# │                                │ trinationalen Agglomeration Es │                           │                           │                           │                           │
# │                                │ wird nach Liniennummer         │                           │                           │                           │                           │
# │                                │ Transportunternehmen und       │                           │                           │                           │                           │
# │                                │ Zeitdauer das Angebots         │                           │                           │                           │                           │
# │                                │ unterschieden.                 │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Rotwildjagd in Teilgebieten    │ Teilgebiete kantonaler         │                           │                           │                           │                           │
# │ von Banngebieten               │ Banngebiete welche während der │                           │                           │                           │                           │
# │                                │ Hochjagd für die Bejagung des  │                           │                           │                           │                           │
# │                                │ Rotwildes offen sind gemäss    │                           │                           │                           │                           │
# │                                │ Art und vom Jahres-Beschluss   │                           │                           │                           │                           │
# │                                │ über die Ausübung der Jagd.    │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Park                           │ Standorte der Parkanlagen in   │ Stadt, Stadt Zürich,      │ Stadt, Stadt Zürich,      │                           │ zürich, stadt             │
# │                                │ der Stadt Zürich Zweck         │ Kontaktparagraphen,       │ Kontaktparagraphen,       │                           │                           │
# │                                │ Auffinden und Darstellen der   │ Stadtplan                 │ Stadtplan                 │                           │                           │
# │                                │ Daten im Kontaktparagraphen    │                           │                           │                           │                           │
# │                                │ der städtischen Internetseiten │                           │                           │                           │                           │
# │                                │ sowie im Stadtplan.            │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Grenzüberschreitender City     │ Dieses Dataset präsentiert die │                           │                           │                           │ city                      │
# │ Statistics Arbeitsmarkt        │ jährlichen                     │                           │                           │                           │                           │
# │ Agglomerationen                │ Arbeitsmarktindikatoren der    │                           │                           │                           │                           │
# │                                │ grenzüberschreitenden City     │                           │                           │                           │                           │
# │                                │ Statistics gemäss der          │                           │                           │                           │                           │
# │                                │ Raumtypologie Erwerbsquote     │                           │                           │                           │                           │
# │                                │ Erwerbstätigenquote            │                           │                           │                           │                           │
# │                                │ Erberbspersonen nach           │                           │                           │                           │                           │
# │                                │ Geschlecht ab .                │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Archäologische Fundstellen     │ Der Datensatz enthält          │ Einzelfund-Stellen,       │ Einzelfund-Stellen,       │                           │ muracher, alt             │
# │                                │ archäologische Fundstellen als │ Muracher                  │ Muracher                  │                           │                           │
# │                                │ interpretierte Flächen wobei   │                           │                           │                           │                           │
# │                                │ unterschieden wird zwischen    │                           │                           │                           │                           │
# │                                │ Stätten die sicher             │                           │                           │                           │                           │
# │                                │ grossflächig sind -Fundstellen │                           │                           │                           │                           │
# │                                │ . BautenSiedlungen             │                           │                           │                           │                           │
# │                                │ GräberFriedhöfe und            │                           │                           │                           │                           │
# │                                │ Einzelfund-Stellen die auf     │                           │                           │                           │                           │
# │                                │ grossflächige Fundstellen      │                           │                           │                           │                           │
# │                                │ hinweisen können -Fundstellen  │                           │                           │                           │                           │
# │                                │ . Steinbeil Die interpretierte │                           │                           │                           │                           │
# │                                │ Darstellung von                │                           │                           │                           │                           │
# │                                │ archäologischen Fundstellen    │                           │                           │                           │                           │
# │                                │ basiert auf Ausgrabungen und   │                           │                           │                           │                           │
# │                                │ auf aktenkundigen              │                           │                           │                           │                           │
# │                                │ Fundmeldungen die teilweise    │                           │                           │                           │                           │
# │                                │ bis zu Jahre alt sind          │                           │                           │                           │                           │
# │                                │ vereinzelt auch auf Flurnamen  │                           │                           │                           │                           │
# │                                │ . Muracher sehr alte           │                           │                           │                           │                           │
# │                                │ Fundmeldungen lassen sich      │                           │                           │                           │                           │
# │                                │ manchmal nur schwierig         │                           │                           │                           │                           │
# │                                │ interpretieren und ungenau     │                           │                           │                           │                           │
# │                                │ lokalisieren Der erste         │                           │                           │                           │                           │
# │                                │ Durchgang der kantonsweiten    │                           │                           │                           │                           │
# │                                │ Erfassung ist Ende             │                           │                           │                           │                           │
# │                                │ abgeschlossen worden die       │                           │                           │                           │                           │
# │                                │ Ausarbeitung und Nachführung   │                           │                           │                           │                           │
# │                                │ wird laufend zu Ergänzungen    │                           │                           │                           │                           │
# │                                │ und einzelnen Änderungen       │                           │                           │                           │                           │
# │                                │ führen Angaben über Datierung  │                           │                           │                           │                           │
# │                                │ Art Umfang und Erhaltungsgrad  │                           │                           │                           │                           │
# │                                │ einer Fundstelle können über   │                           │                           │                           │                           │
# │                                │ die Fundstellennummer die als  │                           │                           │                           │                           │
# │                                │ Attribut auch im GIS-Datensatz │                           │                           │                           │                           │
# │                                │ enthalten ist auf Anfrage      │                           │                           │                           │                           │
# │                                │ erschlossen werden.            │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Orthophoto Liechtenstein       │ Orthophoto mit einer Auflösung │ Echtfarben, RGB           │ Echtfarben, RGB           │                           │                           │
# │                                │ von cm Bodenpixel Es wurde am  │                           │                           │                           │                           │
# │                                │ August geflogen und liegt in   │                           │                           │                           │                           │
# │                                │ Echtfarben RGB als auch in     │                           │                           │                           │                           │
# │                                │ Infrarot CIR vor Das ganze     │                           │                           │                           │                           │
# │                                │ Land inkl Nachbarregion        │                           │                           │                           │                           │
# │                                │ besteht aus Kacheln . . km bzw │                           │                           │                           │                           │
# │                                │ Pixel Eine Kachel hat somit    │                           │                           │                           │                           │
# │                                │ Mpx und eine Grösse von . bis  │                           │                           │                           │                           │
# │                                │ . GB Es können aber auch       │                           │                           │                           │                           │
# │                                │ kleinere georeferenzierte      │                           │                           │                           │                           │
# │                                │ Ausschnitte bestellt werden.   │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Kommunaler Nutzungsplan        │ Zonenplan Siedlung nachgeführt │ Siedlung, Augst, BL,      │ Siedlung, Augst, BL,      │                           │ ebenen, siedlung, augst   │
# │ Gemeinde Augst                 │ und Zonenplan Landschaft       │ Kommunaler, Nutzungsplan, │ Kommunaler, Nutzungsplan, │                           │                           │
# │                                │ nachgeführt der Gemeinde Augst │ Kanton, Kanton BL         │ Kanton, Kanton BL         │                           │                           │
# │                                │ Das Datenmodell teilt den      │                           │                           │                           │                           │
# │                                │ Nutzungsplan in Ebenen auf     │                           │                           │                           │                           │
# │                                │ Grundnutzung Grundflächen      │                           │                           │                           │                           │
# │                                │ orientierenden Inhalts         │                           │                           │                           │                           │
# │                                │ Verbindliche überlagernde      │                           │                           │                           │                           │
# │                                │ Elemente mit Schutzfunktion    │                           │                           │                           │                           │
# │                                │ bzw Nutzungseinschränkung      │                           │                           │                           │                           │
# │                                │ Überlagernde Elemente          │                           │                           │                           │                           │
# │                                │ orientierend Überlagernde      │                           │                           │                           │                           │
# │                                │ Elemente rechtsverbindlich Das │                           │                           │                           │                           │
# │                                │ Attribut Status in den         │                           │                           │                           │                           │
# │                                │ Geodaten kann abgefragt werden │                           │                           │                           │                           │
# ...
# │ Lämmer                         │ im Geburtsjahr Tiere ohne      │                           │                           │                           │                           │
# │                                │ Namen oder mit technischen     │                           │                           │                           │                           │
# │                                │ Namensbezeichnungen werden in  │                           │                           │                           │                           │
# │                                │ der Darstellung nicht          │                           │                           │                           │                           │
# │                                │ berücksichtigt Die Mehrheit    │                           │                           │                           │                           │
# │                                │ aller Namen kommt nur einmal   │                           │                           │                           │                           │
# │                                │ vor und schafft es nicht unter │                           │                           │                           │                           │
# │                                │ die Top .                      │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ RDP Baulinien Weggis           │ Baulinien begrenzen die        │ Nutzungsplanungen         │ Nutzungsplanungen         │                           │                           │
# │                                │ Bebauung und dienen            │                           │                           │                           │                           │
# │                                │ insbesondere der Sicherung     │                           │                           │                           │                           │
# │                                │ bestehender und geplanter      │                           │                           │                           │                           │
# │                                │ Anlagen und Flächen sowie der  │                           │                           │                           │                           │
# │                                │ baulichen Gestaltung Die       │                           │                           │                           │                           │
# │                                │ Strassen und Baulinienpläne    │                           │                           │                           │                           │
# │                                │ dienen dazu den Strassenraum   │                           │                           │                           │                           │
# │                                │ zu gestalten oder Gelände für  │                           │                           │                           │                           │
# │                                │ geplante Strassen              │                           │                           │                           │                           │
# │                                │ freizuhalten.Baulinien können  │                           │                           │                           │                           │
# │                                │ mit folgenden                  │                           │                           │                           │                           │
# │                                │ Planungsinstrumenten erlassen  │                           │                           │                           │                           │
# │                                │ werden:•Baulinien die im       │                           │                           │                           │                           │
# │                                │ Rahmen von Strassen und        │                           │                           │                           │                           │
# │                                │ Baulinienplänen erlassen       │                           │                           │                           │                           │
# │                                │ wurden•Baulinien die im Rahmen │                           │                           │                           │                           │
# │                                │ von kommunalen                 │                           │                           │                           │                           │
# │                                │ Nutzungsplanungen erlassen     │                           │                           │                           │                           │
# │                                │ wurden•Baulinien die im Rahmen │                           │                           │                           │                           │
# │                                │ von Bebauungsplänen erlassen   │                           │                           │                           │                           │
# │                                │ wurdenSiehe Richtlinien zur    │                           │                           │                           │                           │
# │                                │ Erstellung digitaler Baulinien │                           │                           │                           │                           │
# │                                │ Modell .                       │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Neubauwohnungen am Jahresende  │ Der Datensatz enthält die      │ Eigentumsart              │ Eigentumsart              │                           │                           │
# │ nach Bauprojektstatus          │ Anzahl bewilligter und im Bau  │                           │                           │                           │                           │
# │ Eigentumsart und Statistischer │ befindlicher Wohnungen in      │                           │                           │                           │                           │
# │ Zone                           │ Neubauprojekten nach           │                           │                           │                           │                           │
# │                                │ Eigentumsart und statistischer │                           │                           │                           │                           │
# │                                │ Zone.                          │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Planungszonen Stadt Basel &    │ Der Regierungsrat oder         │ Nutzungsplänen            │ Nutzungsplänen            │                           │                           │
# │ Bettingen                      │ Gemeinderat kann Planungszonen │                           │                           │                           │                           │
# │                                │ bestimmen Sie werden auch      │                           │                           │                           │                           │
# │                                │ durch öffentliche Auflage der  │                           │                           │                           │                           │
# │                                │ Entwürfe von Nutzungsplänen    │                           │                           │                           │                           │
# │                                │ begründet.                     │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Gesamtsteuerfuss ohne Kirchen  │ Bezogener Gesamtsteuerfuss     │ Bezogener                 │ Bezogener                 │                           │                           │
# │                                │ ohne Kirchen in Prozent der    │                           │                           │                           │                           │
# │                                │ einfachen Staatssteuer         │                           │                           │                           │                           │
# │                                │ gewichtet mit der Steuerkraft  │                           │                           │                           │                           │
# │                                │ des jeweiligen Jahres          │                           │                           │                           │                           │
# │                                │ Zeitreihe ab neues             │                           │                           │                           │                           │
# │                                │ Finanzausgleichsgesetz Details │                           │                           │                           │                           │
# │                                │ zu angewendeten Steuerfüssen   │                           │                           │                           │                           │
# │                                │ sind direkt bei den jeweiligen │                           │                           │                           │                           │
# │                                │ Gemeinden einzuholen Die Daten │                           │                           │                           │                           │
# │                                │ des aktuellsten Jahr sind      │                           │                           │                           │                           │
# │                                │ provisorisch.                  │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Energierohstoffe               │ Dieser Datensatz zeigt die     │ Energierohstoffen,        │ Energierohstoffen,        │ ##chweiz, ##chweiz        │                           │
# │                                │ Fundorte und ehemaligen        │ Schweiz, der, Schweiz     │ Schweiz, der, Schweiz     │                           │                           │
# │                                │ Abbaustellen von               │                           │                           │                           │                           │
# │                                │ Energierohstoffen in der       │                           │                           │                           │                           │
# │                                │ Schweiz Zurzeit werden in der  │                           │                           │                           │                           │
# │                                │ Schweiz kommerziell keine      │                           │                           │                           │                           │
# │                                │ Energierohstoffe gewonnen.     │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Arbeitsmarktstatistik          │ Im Kanton Zug registrierte     │ Kanton Zug                │ Kanton Zug                │                           │ zug                       │
# │                                │ Anzahl Arbeitslose total nach  │                           │                           │                           │                           │
# │                                │ Altersklasse Anzahl            │                           │                           │                           │                           │
# │                                │ Langzeitarbeitslose und Anzahl │                           │                           │                           │                           │
# │                                │ Stellensuchende pro Monat seit │                           │                           │                           │                           │
# │                                │ .. QUELLE SECO                 │                           │                           │                           │                           │
# ├────────────────────────────────┼────────────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Historischer Übersichtsplan    │ Der Übersichtsplan der Stadt   │ Stadt, Stadt Zürich       │ Stadt, Stadt Zürich       │                           │ zürich, stadt             │
# │ der Stadt Zürich um            │ Zürich ist ein generalisiertes │                           │                           │                           │                           │
# │                                │ Planwerk erstellt aus den      │                           │                           │                           │                           │
# │                                │ Daten der amtlichen Vermessung │                           │                           │                           │                           │
# │                                │ Stand Zweck Der Übersichtsplan │                           │                           │                           │                           │
# │                                │ dient der Orientierung im Raum │                           │                           │                           │                           │
# │                                │ Referenzdaten und eignet sich  │                           │                           │                           │                           │
# │                                │ als Hintergrundkarte zur       │                           │                           │                           │                           │
# │                                │ Darstellung von beliebigen     │                           │                           │                           │                           │
# │                                │ Fachdaten im historischen      │                           │                           │                           │                           │
# │                                │ Kontext.                       │                           │                           │                           │                           │
# └────────────────────────────────┴────────────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────┘
